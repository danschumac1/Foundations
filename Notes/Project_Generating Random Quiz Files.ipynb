# %% [markdown]
# # Project: Generating Random Quiz Files

# %% [markdown]
# Say you’re a geography teacher with 35 students in your class and you want to give a pop quiz on US state capitals. Alas, your class has a few bad eggs in it, and you can’t trust the students not to cheat. You’d like to randomize the order of questions so that each quiz is unique, making it impossible for anyone to crib answers from anyone else. Of course, doing this by hand would be a lengthy and boring affair. Fortunately, you know some Python.
#
#     Here is what the program does:
#
#     1. Creates 35 different quizzes
#     2. Creates 50 multiple-choice questions for each quiz, in random order
#     3. Provides the correct answer and three random wrong answers for each question, in random order
#     4. Writes the quizzes to 35 text files
#     5. Writes the answer keys to 35 text files
#
#     This means the code will need to do the following:
#
#     1. Store the states and their capitals in a dictionary
#     2. Call open(), write(), and close() for the quiz and answer key text files
#     3. Use random.shuffle() to randomize the order of the questions and multiple-choice options

# %%
import random

# %%
capitals = {'Alabama': 'Montgomery',
            'Alaska': 'Juneau',
            'Arizona': 'Phoenix',
            'Arkansas': 'Little Rock',
            'California': 'Sacramento',
            'Colorado': 'Denver',
            'Connecticut': 'Hartford',
            'Delaware': 'Dover',
            'Florida': 'Tallahassee',
            'Georgia': 'Atlanta',
                       'Hawaii': 'Honolulu',
                       'Idaho': 'Boise',
                       'Illinois':'Springfield',
                       'Indiana': 'Indianapolis',
                       'Iowa': 'Des Moines',
                       'Kansas':'Topeka',
                       'Kentucky': 'Frankfort',
                       'Louisiana': 'Baton Rouge',
                       'Maine':'Augusta',
                       'Maryland': 'Annapolis',
                       'Massachusetts': 'Boston',
                       'Michigan':'Lansing',
                       'Minnesota': 'Saint Paul',
                       'Mississippi': 'Jackson',
                       'Missouri':'Jefferson City',
                       'Montana': 'Helena',
                       'Nebraska': 'Lincoln',
                       'Nevada':'Carson City',
                       'New Hampshire': 'Concord',
                       'New Jersey': 'Trenton',
                       'New Mexico': 'Santa Fe',
                       'New York': 'Albany',
                       'North Carolina': 'Raleigh',
                       'North Dakota': 'Bismarck',
                       'Ohio': 'Columbus',
                       'Oklahoma': 'Oklahoma City',
                       'Oregon': 'Salem',
                       'Pennsylvania': 'Harrisburg',
                       'Rhode Island': 'Providence',
                       'South Carolina': 'Columbia',
                       'South Dakota': 'Pierre',
                       'Tennessee':'Nashville',
                       'Texas': 'Austin',
                       'Utah': 'Salt Lake City',
                       'Vermont':'Montpelier',
                       'Virginia': 'Richmond',
                       'Washington': 'Olympia',
                       'West Virginia': 'Charleston',
                       'Wisconsin': 'Madison',
                       'Wyoming': 'Cheyenne'}

# %%
states = list(capitals.keys())
capital_cities = list(capitals.values())

test1 = open('Tests/test1.txt', 'w')
test1.write('TEST\nID:1\n\n')
test1.close()

testkey1 = open('Test Keys/testkey1.txt', 'w')
testkey1.write('TESTKEY\nID:1\n\n')
testkey1.close()

#Generate a Randomized Test
test1 = open('Tests/test1.txt','a')
testkey1 = open('Test Keys/testkey1.txt', 'a')

for question in range(1,51):
    #randomize order of states and cities
    random.shuffle(capital_cities)
    random.shuffle(states)
    
    #pick the state we will ask about. And remove it from states (no duplicate questions)
    state = states.pop()
    print(f'{question}) What is the capital of {state}?\n')
    test1.write(f'{question}) What is the capital of {state}?\n')
    
    #append 3 wrong answers to the answer list
    correct_answer = capitals[state]
    answers = [city for city in capital_cities if city != correct_answer][0:3]
    #append the correct answer to the answer list
    answers.append(correct_answer)
    #shuffle answers
    random.shuffle(answers)
    #print answer choices
    print(f'A: {answers[0]}\nB: {answers[1]}\nC: {answers[2]}\nD: {answers[3]}\n\n')
    test1.write(f'A: {answers[0]}\nB: {answers[1]}\nC: {answers[2]}\nD: {answers[3]}\n\n')
    
    
    #FOR ANSWER KEY
    answer_loc = answers.index(correct_answer)
    index_to_alpha = str.maketrans('0123','ABCD')
    answer_alpha = str(answer_loc).translate(index_to_alpha)
    testkey1.write(f'{question}) {answer_alpha}\n')
    
test1.close()
testkey1.close()
# Out:
# 1) What is the capital of Maine?
#
# A: Annapolis
# B: Augusta
# C: Concord
# D: Tallahassee
#
#
# 2) What is the capital of New Jersey?
#
# A: Honolulu
# B: Trenton
# C: Des Moines
# D: Phoenix
#
#
# 3) What is the capital of Louisiana?
#
# A: Baton Rouge
# B: Phoenix
# C: Salt Lake City
# D: Sacramento
#
#
# 4) What is the capital of Wyoming?
#
# A: Concord
# B: Lansing
# C: Dover
# D: Cheyenne
#
#
# 5) What is the capital of Minnesota?
#
# A: Santa Fe
# B: Charleston
# C: Saint Paul
# D: Concord
#
#
# 6) What is the capital of Mississippi?
#
# A: Baton Rouge
# B: Jackson
# C: Montpelier
# D: Albany
#
#
# 7) What is the capital of North Carolina?
#
# A: Indianapolis
# B: Baton Rouge
# C: Raleigh
# D: Des Moines
#
#
# 8) What is the capital of California?
#
# A: Sacramento
# B: Helena
# C: Trenton
# D: Little Rock
#
#
# 9) What is the capital of Virginia?
#
# A: Springfield
# B: Baton Rouge
# C: Richmond
# D: Oklahoma City
#
#
# 10) What is the capital of Massachusetts?
#
# A: Denver
# B: Boston
# C: Richmond
# D: Little Rock
#
#
# 11) What is the capital of Illinois?
#
# A: Saint Paul
# B: Honolulu
# C: Phoenix
# D: Springfield
#
#
# 12) What is the capital of Kentucky?
#
# A: Frankfort
# B: Austin
# C: Charleston
# D: Tallahassee
#
#
# 13) What is the capital of Rhode Island?
#
# A: Saint Paul
# B: Providence
# C: Albany
# D: Denver
#
#
# 14) What is the capital of Iowa?
#
# A: Sacramento
# B: Des Moines
# C: Saint Paul
# D: Atlanta
#
#
# 15) What is the capital of Wisconsin?
#
# A: Madison
# B: Helena
# C: Nashville
# D: Pierre
#
#
# 16) What is the capital of Idaho?
#
# A: Boise
# B: Helena
# C: Concord
# D: Charleston
#
#
# 17) What is the capital of Delaware?
#
# A: Augusta
# B: Phoenix
# C: Denver
# D: Dover
#
#
# 18) What is the capital of Montana?
#
# A: Jackson
# B: Springfield
# C: Atlanta
# D: Helena
#
#
# 19) What is the capital of Utah?
#
# A: Columbia
# B: Montgomery
# C: Olympia
# D: Salt Lake City
#
#
# 20) What is the capital of Florida?
#
# A: Montgomery
# B: Indianapolis
# C: Raleigh
# D: Tallahassee
#
#
# 21) What is the capital of Nevada?
#
# A: Montpelier
# B: Juneau
# C: Carson City
# D: Des Moines
#
#
# 22) What is the capital of Alaska?
#
# A: Santa Fe
# B: Juneau
# C: Atlanta
# D: Phoenix
#
#
# 23) What is the capital of Alabama?
#
# A: Montgomery
# B: Richmond
# C: Montpelier
# D: Cheyenne
#
#
# 24) What is the capital of New Hampshire?
#
# A: Concord
# B: Olympia
# C: Trenton
# D: Tallahassee
#
#
# 25) What is the capital of Kansas?
#
# A: Topeka
# B: Santa Fe
# C: Boston
# D: Albany
#
#
# 26) What is the capital of South Carolina?
#
# A: Springfield
# B: Columbia
# C: Honolulu
# D: Juneau
#
#
# 27) What is the capital of Michigan?
#
# A: Madison
# B: Lansing
# C: Frankfort
# D: Indianapolis
#
#
# 28) What is the capital of Indiana?
#
# A: Bismarck
# B: Atlanta
# C: Richmond
# D: Indianapolis
#
#
# 29) What is the capital of Texas?
#
# A: Austin
# B: Olympia
# C: Indianapolis
# D: Columbus
#
#
# 30) What is the capital of Missouri?
#
# A: Dover
# B: Frankfort
# C: Cheyenne
# D: Jefferson City
#
#
# 31) What is the capital of Pennsylvania?
#
# A: Salt Lake City
# B: Little Rock
# C: Jackson
# D: Harrisburg
#
#
# 32) What is the capital of Washington?
#
# A: Denver
# B: Topeka
# C: Olympia
# D: Jefferson City
#
#
# 33) What is the capital of Connecticut?
#
# A: Hartford
# B: Helena
# C: Nashville
# D: Springfield
#
#
# 34) What is the capital of Georgia?
#
# A: Juneau
# B: Columbus
# C: Atlanta
# D: Cheyenne
#
#
# 35) What is the capital of Maryland?
#
# A: Denver
# B: Annapolis
# C: Phoenix
# D: Montgomery
#
#
# 36) What is the capital of South Dakota?
#
# A: Olympia
# B: Topeka
# C: Columbia
# D: Pierre
#
#
# 37) What is the capital of Oregon?
#
# A: Salem
# B: Harrisburg
# C: Frankfort
# D: Saint Paul
#
#
# 38) What is the capital of Vermont?
#
# A: Pierre
# B: Oklahoma City
# C: Cheyenne
# D: Montpelier
#
#
# 39) What is the capital of Nebraska?
#
# A: Helena
# B: Baton Rouge
# C: Harrisburg
# D: Lincoln
#
#
# 40) What is the capital of Arkansas?
#
# A: Atlanta
# B: Olympia
# C: Boise
# D: Little Rock
#
#
# 41) What is the capital of Oklahoma?
#
# A: Raleigh
# B: Oklahoma City
# C: Jefferson City
# D: Sacramento
#
#
# 42) What is the capital of West Virginia?
#
# A: Columbia
# B: Jackson
# C: Charleston
# D: Carson City
#
#
# 43) What is the capital of Hawaii?
#
# A: Honolulu
# B: Madison
# C: Montpelier
# D: Salt Lake City
#
#
# 44) What is the capital of Colorado?
#
# A: Denver
# B: Springfield
# C: Providence
# D: Montgomery
#
#
# 45) What is the capital of New Mexico?
#
# A: Dover
# B: Santa Fe
# C: Pierre
# D: Hartford
#
#
# 46) What is the capital of New York?
#
# A: Hartford
# B: Albany
# C: Pierre
# D: Providence
#
#
# 47) What is the capital of Ohio?
#
# A: Columbus
# B: Nashville
# C: Salt Lake City
# D: Phoenix
#
#
# 48) What is the capital of North Dakota?
#
# A: Dover
# B: Atlanta
# C: Bismarck
# D: Tallahassee
#
#
# 49) What is the capital of Arizona?
#
# A: Des Moines
# B: Boston
# C: Columbus
# D: Phoenix
#
#
# 50) What is the capital of Tennessee?
#
# A: Topeka
# B: Des Moines
# C: Nashville
# D: Carson City

# %%
answer_alpha
# Out:
# 'C'

# %%
#make a unique test for each student
for ID in range(1,36):

    states = list(capitals.keys())
    capital_cities = list(capitals.values())

    test = open(f'Tests/test{ID}.txt', 'w')
    test.write(f'TEST\nID:{ID}\n\n')
    test.close()

    testkey = open(f'Test Keys/testkey{ID}.txt', 'w')
    testkey.write(f'TESTKEY\nID:{ID}\n\n')
    testkey.close()

    #Generate a Randomized Test
    test = open(f'Tests/test{ID}.txt','a')
    testkey = open(f'Test Keys/testkey{ID}.txt', 'a')

    for question in range(1,51):
        #randomize order of states and cities
        random.shuffle(capital_cities)
        random.shuffle(states)

        #pick the state we will ask about. And remove it from states (no duplicate questions)
        state = states.pop()
        print(f'{question}) What is the capital of {state}?\n')
        test.write(f'{question}) What is the capital of {state}?\n')

        #append 3 wrong answers to the answer list
        correct_answer = capitals[state]
        answers = [city for city in capital_cities if city != correct_answer][0:3]
        #append the correct answer to the answer list
        answers.append(correct_answer)
        #shuffle answers
        random.shuffle(answers)
        #print answer choices
        print(f'A: {answers[0]}\nB: {answers[1]}\nC: {answers[2]}\nD: {answers[3]}\n\n')
        test.write(f'A: {answers[0]}\nB: {answers[1]}\nC: {answers[2]}\nD: {answers[3]}\n\n')


        #FOR ANSWER KEY
        #find index location of correct answer
        answer_loc = answers.index(correct_answer)
        index_to_alpha = str.maketrans('0123','ABCD')
        #translate index value to A,B,C or D
        answer_alpha = str(answer_loc).translate(index_to_alpha)
        #write to answer key
        testkey.write(f'{question}) {answer_alpha}\n')
    
    test.close()
    testkey.close()
# Out:
# 1) What is the capital of North Dakota?
#
# A: Nashville
# B: Bismarck
# C: Honolulu
# D: Harrisburg
#
#
# 2) What is the capital of Rhode Island?
#
# A: Providence
# B: Springfield
# C: Annapolis
# D: Jefferson City
#
#
# 3) What is the capital of Iowa?
#
# A: Springfield
# B: Albany
# C: Salt Lake City
# D: Des Moines
#
#
# 4) What is the capital of Ohio?
#
# A: Jefferson City
# B: Salem
# C: Columbus
# D: Montgomery
#
#
# 5) What is the capital of Delaware?
#
# A: Providence
# B: Columbia
# C: Dover
# D: Jefferson City
#
#
# 6) What is the capital of Washington?
#
# A: Olympia
# B: Baton Rouge
# C: Carson City
# D: Raleigh
#
#
# 7) What is the capital of New Jersey?
#
# A: Little Rock
# B: Nashville
# C: Trenton
# D: Cheyenne
#
#
# 8) What is the capital of South Dakota?
#
# A: Pierre
# B: Madison
# C: Charleston
# D: Harrisburg
#
#
# 9) What is the capital of West Virginia?
#
# A: Des Moines
# B: Providence
# C: Charleston
# D: Hartford
#
#
# 10) What is the capital of Wisconsin?
#
# A: Columbia
# B: Madison
# C: Helena
# D: Tallahassee
#
#
# 11) What is the capital of Vermont?
#
# A: Cheyenne
# B: Montpelier
# C: Augusta
# D: Bismarck
#
#
# 12) What is the capital of Missouri?
#
# A: Trenton
# B: Albany
# C: Atlanta
# D: Jefferson City
#
#
# 13) What is the capital of South Carolina?
#
# A: Baton Rouge
# B: Columbia
# C: Juneau
# D: Frankfort
#
#
# 14) What is the capital of Alaska?
#
# A: Salt Lake City
# B: Indianapolis
# C: Juneau
# D: Providence
#
#
# 15) What is the capital of Minnesota?
#
# A: Cheyenne
# B: Saint Paul
# C: Bismarck
# D: Harrisburg
#
#
# 16) What is the capital of New York?
#
# A: Phoenix
# B: Albany
# C: Pierre
# D: Frankfort
#
#
# 17) What is the capital of Maine?
#
# A: Pierre
# B: Augusta
# C: Raleigh
# D: Honolulu
#
#
# 18) What is the capital of Massachusetts?
#
# A: Bismarck
# B: Providence
# C: Boston
# D: Cheyenne
#
#
# 19) What is the capital of Georgia?
#
# A: Atlanta
# B: Harrisburg
# C: Juneau
# D: Honolulu
#
#
# 20) What is the capital of Kentucky?
#
# A: Jackson
# B: Columbus
# C: Frankfort
# D: Sacramento
#
#
# 21) What is the capital of Pennsylvania?
#
# A: Austin
# B: Denver
# C: Harrisburg
# D: Columbus
#
#
# 22) What is the capital of Arizona?
#
# A: Frankfort
# B: Topeka
# C: Phoenix
# D: Providence
#
#
# 23) What is the capital of Nebraska?
#
# A: Dover
# B: Lincoln
# C: Helena
# D: Montpelier
#
#
# 24) What is the capital of Arkansas?
#
# A: Hartford
# B: Pierre
# C: Dover
# D: Little Rock
#
#
# 25) What is the capital of Connecticut?
#
# A: Cheyenne
# B: Hartford
# C: Little Rock
# D: Charleston
#
#
# 26) What is the capital of Alabama?
#
# A: Frankfort
# B: Sacramento
# C: Montgomery
# D: Salem
#
#
# 27) What is the capital of Oregon?
#
# A: Austin
# B: Pierre
# C: Nashville
# D: Salem
#
#
# 28) What is the capital of North Carolina?
#
# A: Phoenix
# B: Raleigh
# C: Albany
# D: Honolulu
#
#
# 29) What is the capital of New Hampshire?
#
# A: Bismarck
# B: Oklahoma City
# C: Concord
# D: Jackson
#
#
# 30) What is the capital of Kansas?
#
# A: Harrisburg
# B: Madison
# C: Topeka
# D: Denver
#
#
# 31) What is the capital of Colorado?
#
# A: Denver
# B: Olympia
# C: Boise
# D: Boston
#
#
# 32) What is the capital of Idaho?
#
# A: Lincoln
# B: Boise
# C: Juneau
# D: Helena
#
#
# 33) What is the capital of Oklahoma?
#
# A: Santa Fe
# B: Oklahoma City
# C: Charleston
# D: Juneau
#
#
# 34) What is the capital of Nevada?
#
# A: Austin
# B: Juneau
# C: Jackson
# D: Carson City
#
#
# 35) What is the capital of New Mexico?
#
# A: Saint Paul
# B: Columbus
# C: Santa Fe
# D: Pierre
#
#
# 36) What is the capital of Virginia?
#
# A: Columbus
# B: Lansing
# C: Richmond
# D: Bismarck
#
#
# 37) What is the capital of Texas?
#
# A: Lansing
# B: Dover
# C: Columbus
# D: Austin
#
#
# 38) What is the capital of Tennessee?
#
# A: Austin
# B: Jackson
# C: Salt Lake City
# D: Nashville
#
#
# 39) What is the capital of Mississippi?
#
# A: Topeka
# B: Jackson
# C: Des Moines
# D: Trenton
#
#
# 40) What is the capital of Florida?
#
# A: Frankfort
# B: Tallahassee
# C: Lansing
# D: Saint Paul
#
#
# 41) What is the capital of Hawaii?
#
# A: Lansing
# B: Honolulu
# C: Augusta
# D: Raleigh
#
#
# 42) What is the capital of California?
#
# A: Austin
# B: Annapolis
# C: Oklahoma City
# D: Sacramento
#
#
# 43) What is the capital of Montana?
#
# A: Phoenix
# B: Helena
# C: Austin
# D: Richmond
#
#
# 44) What is the capital of Maryland?
#
# A: Salem
# B: Atlanta
# C: Cheyenne
# D: Annapolis
#
#
# 45) What is the capital of Louisiana?
#
# A: Helena
# B: Annapolis
# C: Denver
# D: Baton Rouge
#
#
# 46) What is the capital of Illinois?
#
# A: Olympia
# B: Boston
# C: Pierre
# D: Springfield
#
#
# 47) What is the capital of Utah?
#
# A: Trenton
# B: Annapolis
# C: Salt Lake City
# D: Honolulu
#
#
# 48) What is the capital of Wyoming?
#
# A: Phoenix
# B: Cheyenne
# C: Oklahoma City
# D: Austin
#
#
# 49) What is the capital of Michigan?
#
# A: Charleston
# B: Topeka
# C: Des Moines
# D: Lansing
#
#
# 50) What is the capital of Indiana?
#
# A: Boston
# B: Indianapolis
# C: Raleigh
# D: Sacramento
#
#
# 1) What is the capital of Montana?
#
# A: Lincoln
# B: Hartford
# C: Pierre
# D: Helena
#
#
# 2) What is the capital of Nevada?
#
# A: Juneau
# B: Tallahassee
# C: Carson City
# D: Atlanta
#
#
# 3) What is the capital of Colorado?
#
# A: Denver
# B: Little Rock
# C: Augusta
# D: Jefferson City
#
#
# 4) What is the capital of Idaho?
#
# A: Boise
# B: Dover
# C: Harrisburg
# D: Columbia
#
#
# 5) What is the capital of Massachusetts?
#
# A: Boston
# B: Indianapolis
# C: Cheyenne
# D: Springfield
#
#
# 6) What is the capital of Maryland?
#
# A: Oklahoma City
# B: Raleigh
# C: Columbus
# D: Annapolis
#
#
# 7) What is the capital of New York?
#
# A: Albany
# B: Jefferson City
# C: Bismarck
# D: Augusta
#
#
# 8) What is the capital of Oklahoma?
#
# A: Topeka
# B: Oklahoma City
# C: Indianapolis
# D: Augusta
#
#
# 9) What is the capital of Iowa?
#
# A: Boise
# B: Des Moines
# C: Charleston
# D: Columbus
#
#
# 10) What is the capital of Delaware?
#
# A: Richmond
# B: Jefferson City
# C: Dover
# D: Sacramento
#
#
# 11) What is the capital of Arizona?
#
# A: Jackson
# B: Honolulu
# C: Boston
# D: Phoenix
#
#
# 12) What is the capital of Rhode Island?
#
# A: Cheyenne
# B: Topeka
# C: Atlanta
# D: Providence
#
#
# 13) What is the capital of Nebraska?
#
# A: Columbia
# B: Lincoln
# C: Augusta
# D: Cheyenne
#
#
# 14) What is the capital of Vermont?
#
# A: Santa Fe
# B: Helena
# C: Montpelier
# D: Jackson
#
#
# 15) What is the capital of New Jersey?
#
# A: Trenton
# B: Juneau
# C: Boise
# D: Harrisburg
#
#
# 16) What is the capital of Arkansas?
#
# A: Charleston
# B: Boise
# C: Little Rock
# D: Hartford
#
#
# 17) What is the capital of New Mexico?
#
# A: Santa Fe
# B: Richmond
# C: Atlanta
# D: Jackson
#
#
# 18) What is the capital of North Dakota?
#
# A: Bismarck
# B: Denver
# C: Raleigh
# D: Baton Rouge
#
#
# 19) What is the capital of Indiana?
#
# A: Albany
# B: Annapolis
# C: Oklahoma City
# D: Indianapolis
#
#
# 20) What is the capital of Alabama?
#
# A: Charleston
# B: Oklahoma City
# C: Montgomery
# D: Sacramento
#
#
# 21) What is the capital of Mississippi?
#
# A: Olympia
# B: Little Rock
# C: Jackson
# D: Santa Fe
#
#
# 22) What is the capital of Oregon?
#
# A: Jefferson City
# B: Concord
# C: Des Moines
# D: Salem
#
#
# 23) What is the capital of Wisconsin?
#
# A: Salem
# B: Albany
# C: Madison
# D: Montpelier
#
#
# 24) What is the capital of Illinois?
#
# A: Springfield
# B: Olympia
# C: Topeka
# D: Madison
#
#
# 25) What is the capital of Florida?
#
# A: Tallahassee
# B: Lincoln
# C: Indianapolis
# D: Oklahoma City
#
#
# 26) What is the capital of West Virginia?
#
# A: Charleston
# B: Tallahassee
# C: Atlanta
# D: Jefferson City
#
#
# 27) What is the capital of Washington?
#
# A: Jefferson City
# B: Annapolis
# C: Olympia
# D: Phoenix
#
#
# 28) What is the capital of Wyoming?
#
# A: Des Moines
# B: Topeka
# C: Pierre
# D: Cheyenne
#
#
# 29) What is the capital of Virginia?
#
# A: Annapolis
# B: Baton Rouge
# C: Jackson
# D: Richmond
#
#
# 30) What is the capital of Maine?
#
# A: Salt Lake City
# B: Saint Paul
# C: Augusta
# D: Cheyenne
#
#
# 31) What is the capital of New Hampshire?
#
# A: Cheyenne
# B: Olympia
# C: Raleigh
# D: Concord
#
#
# 32) What is the capital of Alaska?
#
# A: Juneau
# B: Columbus
# C: Atlanta
# D: Salem
#
#
# 33) What is the capital of South Carolina?
#
# A: Nashville
# B: Albany
# C: Oklahoma City
# D: Columbia
#
#
# 34) What is the capital of Kentucky?
#
# A: Phoenix
# B: Charleston
# C: Austin
# D: Frankfort
#
#
# 35) What is the capital of Michigan?
#
# A: Denver
# B: Hartford
# C: Lansing
# D: Charleston
#
#
# 36) What is the capital of Minnesota?
#
# A: Cheyenne
# B: Saint Paul
# C: Nashville
# D: Sacramento
#
#
# 37) What is the capital of Louisiana?
#
# A: Madison
# B: Baton Rouge
# C: Montgomery
# D: Richmond
#
#
# 38) What is the capital of California?
#
# A: Boise
# B: Sacramento
# C: Raleigh
# D: Bismarck
#
#
# 39) What is the capital of North Carolina?
#
# A: Little Rock
# B: Raleigh
# C: Providence
# D: Indianapolis
#
#
# 40) What is the capital of Texas?
#
# A: Austin
# B: Augusta
# C: Nashville
# D: Raleigh
#
#
# 41) What is the capital of Tennessee?
#
# A: Indianapolis
# B: Austin
# C: Nashville
# D: Lincoln
#
#
# 42) What is the capital of Hawaii?
#
# A: Honolulu
# B: Carson City
# C: Atlanta
# D: Denver
#
#
# 43) What is the capital of Kansas?
#
# A: Trenton
# B: Boise
# C: Topeka
# D: Denver
#
#
# 44) What is the capital of Utah?
#
# A: Honolulu
# B: Jefferson City
# C: Raleigh
# D: Salt Lake City
#
#
# 45) What is the capital of Pennsylvania?
#
# A: Harrisburg
# B: Charleston
# C: Oklahoma City
# D: Sacramento
#
#
# 46) What is the capital of Ohio?
#
# A: Columbus
# B: Indianapolis
# C: Tallahassee
# D: Des Moines
#
#
# 47) What is the capital of Missouri?
#
# A: Dover
# B: Austin
# C: Harrisburg
# D: Jefferson City
#
#
# 48) What is the capital of South Dakota?
#
# A: Montpelier
# B: Helena
# C: Austin
# D: Pierre
#
#
# 49) What is the capital of Connecticut?
#
# A: Hartford
# B: Topeka
# C: Salem
# D: Baton Rouge
#
#
# 50) What is the capital of Georgia?
#
# A: Columbus
# B: Boston
# C: Atlanta
# D: Olympia
#
#
# 1) What is the capital of Maine?
#
# A: Richmond
# B: Sacramento
# C: Augusta
# D: Austin
#
#
# 2) What is the capital of Georgia?
#
# A: Augusta
# B: Atlanta
# C: Frankfort
# D: Little Rock
#
#
# 3) What is the capital of Mississippi?
#
# A: Jackson
# B: Bismarck
# C: Phoenix
# D: Baton Rouge
#
#
# 4) What is the capital of South Dakota?
#
# A: Pierre
# B: Tallahassee
# C: Frankfort
# D: Jefferson City
#
#
# 5) What is the capital of Iowa?
#
# A: Jackson
# B: Denver
# C: Columbus
# D: Des Moines
#
#
# 6) What is the capital of Arizona?
#
# A: Boston
# B: Madison
# C: Phoenix
# D: Baton Rouge
#
#
# 7) What is the capital of Massachusetts?
#
# A: Phoenix
# B: Denver
# C: Augusta
# D: Boston
#
#
# 8) What is the capital of Alabama?
#
# A: Boise
# B: Montgomery
# C: Indianapolis
# D: Tallahassee
#
#
# 9) What is the capital of Maryland?
#
# A: Columbus
# B: Annapolis
# C: Jefferson City
# D: Montpelier
#
#
# 10) What is the capital of Oregon?
#
# A: Juneau
# B: Hartford
# C: Salem
# D: Salt Lake City
#
#
# 11) What is the capital of Nevada?
#
# A: Boston
# B: Carson City
# C: Salt Lake City
# D: Montgomery
#
#
# 12) What is the capital of Virginia?
#
# A: Richmond
# B: Saint Paul
# C: Charleston
# D: Salem
#
#
# 13) What is the capital of Montana?
#
# A: Denver
# B: Trenton
# C: Jefferson City
# D: Helena
#
#
# 14) What is the capital of North Dakota?
#
# A: Montgomery
# B: Bismarck
# C: Salem
# D: Harrisburg
#
#
# 15) What is the capital of Missouri?
#
# A: Trenton
# B: Jefferson City
# C: Madison
# D: Denver
#
#
# 16) What is the capital of Pennsylvania?
#
# A: Harrisburg
# B: Sacramento
# C: Indianapolis
# D: Denver
#
#
# 17) What is the capital of Idaho?
#
# A: Boise
# B: Hartford
# C: Charleston
# D: Juneau
#
#
# 18) What is the capital of Alaska?
#
# A: Raleigh
# B: Juneau
# C: Topeka
# D: Annapolis
#
#
# 19) What is the capital of Michigan?
#
# A: Frankfort
# B: Lansing
# C: Carson City
# D: Atlanta
#
#
# 20) What is the capital of Delaware?
#
# A: Tallahassee
# B: Dover
# C: Oklahoma City
# D: Bismarck
#
#
# 21) What is the capital of Minnesota?
#
# A: Lincoln
# B: Atlanta
# C: Saint Paul
# D: Hartford
#
#
# 22) What is the capital of Illinois?
#
# A: Harrisburg
# B: Little Rock
# C: Nashville
# D: Springfield
#
#
# 23) What is the capital of West Virginia?
#
# A: Charleston
# B: Providence
# C: Madison
# D: Olympia
#
#
# 24) What is the capital of Wisconsin?
#
# A: Santa Fe
# B: Phoenix
# C: Augusta
# D: Madison
#
#
# 25) What is the capital of Arkansas?
#
# A: Jackson
# B: Frankfort
# C: Helena
# D: Little Rock
#
#
# 26) What is the capital of Florida?
#
# A: Indianapolis
# B: Tallahassee
# C: Austin
# D: Little Rock
#
#
# 27) What is the capital of Ohio?
#
# A: Denver
# B: Montgomery
# C: Sacramento
# D: Columbus
#
#
# 28) What is the capital of New York?
#
# A: Columbia
# B: Topeka
# C: Honolulu
# D: Albany
#
#
# 29) What is the capital of Wyoming?
#
# A: Jackson
# B: Des Moines
# C: Cheyenne
# D: Indianapolis
#
#
# 30) What is the capital of New Mexico?
#
# A: Juneau
# B: Annapolis
# C: Santa Fe
# D: Atlanta
#
#
# 31) What is the capital of Tennessee?
#
# A: Nashville
# B: Columbia
# C: Harrisburg
# D: Helena
#
#
# 32) What is the capital of New Hampshire?
#
# A: Concord
# B: Trenton
# C: Boston
# D: Salt Lake City
#
#
# 33) What is the capital of Vermont?
#
# A: Nashville
# B: Providence
# C: Montpelier
# D: Harrisburg
#
#
# 34) What is the capital of Connecticut?
#
# A: Madison
# B: Indianapolis
# C: Hartford
# D: Harrisburg
#
#
# 35) What is the capital of Kentucky?
#
# A: Sacramento
# B: Phoenix
# C: Frankfort
# D: Montgomery
#
#
# 36) What is the capital of Utah?
#
# A: Annapolis
# B: Salt Lake City
# C: Juneau
# D: Sacramento
#
#
# 37) What is the capital of Rhode Island?
#
# A: Des Moines
# B: Hartford
# C: Providence
# D: Cheyenne
#
#
# 38) What is the capital of South Carolina?
#
# A: Nashville
# B: Indianapolis
# C: Topeka
# D: Columbia
#
#
# 39) What is the capital of Nebraska?
#
# A: Carson City
# B: Salem
# C: Charleston
# D: Lincoln
#
#
# 40) What is the capital of New Jersey?
#
# A: Albany
# B: Trenton
# C: Tallahassee
# D: Lansing
#
#
# 41) What is the capital of Indiana?
#
# A: Boston
# B: Indianapolis
# C: Salt Lake City
# D: Concord
#
#
# 42) What is the capital of North Carolina?
#
# A: Pierre
# B: Hartford
# C: Raleigh
# D: Oklahoma City
#
#
# 43) What is the capital of California?
#
# A: Tallahassee
# B: Sacramento
# C: Des Moines
# D: Phoenix
#
#
# 44) What is the capital of Colorado?
#
# A: Denver
# B: Montpelier
# C: Richmond
# D: Providence
#
#
# 45) What is the capital of Oklahoma?
#
# A: Phoenix
# B: Bismarck
# C: Albany
# D: Oklahoma City
#
#
# 46) What is the capital of Texas?
#
# A: Hartford
# B: Austin
# C: Madison
# D: Baton Rouge
#
#
# 47) What is the capital of Hawaii?
#
# A: Honolulu
# B: Hartford
# C: Jefferson City
# D: Columbia
#
#
# 48) What is the capital of Washington?
#
# A: Annapolis
# B: Charleston
# C: Olympia
# D: Sacramento
#
#
# 49) What is the capital of Kansas?
#
# A: Harrisburg
# B: Little Rock
# C: Topeka
# D: Denver
#
#
# 50) What is the capital of Louisiana?
#
# A: Carson City
# B: Hartford
# C: Nashville
# D: Baton Rouge
#
#
# 1) What is the capital of Arizona?
#
# A: Oklahoma City
# B: Phoenix
# C: Jefferson City
# D: Montpelier
#
#
# 2) What is the capital of Missouri?
#
# A: Harrisburg
# B: Jefferson City
# C: Columbia
# D: Frankfort
#
#
# 3) What is the capital of Virginia?
#
# A: Juneau
# B: Oklahoma City
# C: Boise
# D: Richmond
#
#
# 4) What is the capital of Louisiana?
#
# A: Baton Rouge
# B: Little Rock
# C: Bismarck
# D: Annapolis
#
#
# 5) What is the capital of Utah?
#
# A: Salt Lake City
# B: Cheyenne
# C: Baton Rouge
# D: Helena
#
#
# 6) What is the capital of Wyoming?
#
# A: Des Moines
# B: Cheyenne
# C: Columbia
# D: Lansing
#
#
# 7) What is the capital of Alabama?
#
# A: Boston
# B: Montgomery
# C: Austin
# D: Santa Fe
#
#
# 8) What is the capital of Georgia?
#
# A: Columbia
# B: Austin
# C: Jackson
# D: Atlanta
#
#
# 9) What is the capital of Minnesota?
#
# A: Salem
# B: Saint Paul
# C: Montgomery
# D: Carson City
#
#
# 10) What is the capital of West Virginia?
#
# A: Salt Lake City
# B: Charleston
# C: Sacramento
# D: Springfield
#
#
# 11) What is the capital of Tennessee?
#
# A: Richmond
# B: Madison
# C: Nashville
# D: Harrisburg
#
#
# 12) What is the capital of Florida?
#
# A: Saint Paul
# B: Oklahoma City
# C: Phoenix
# D: Tallahassee
#
#
# 13) What is the capital of Connecticut?
#
# A: Honolulu
# B: Hartford
# C: Nashville
# D: Raleigh
#
#
# 14) What is the capital of Rhode Island?
#
# A: Providence
# B: Phoenix
# C: Little Rock
# D: Salem
#
#
# 15) What is the capital of Wisconsin?
#
# A: Saint Paul
# B: Madison
# C: Columbia
# D: Annapolis
#
#
# 16) What is the capital of Vermont?
#
# A: Little Rock
# B: Providence
# C: Montpelier
# D: Denver
#
#
# 17) What is the capital of Idaho?
#
# A: Albany
# B: Lansing
# C: Santa Fe
# D: Boise
#
#
# 18) What is the capital of Indiana?
#
# A: Springfield
# B: Raleigh
# C: Atlanta
# D: Indianapolis
#
#
# 19) What is the capital of Pennsylvania?
#
# A: Montgomery
# B: Augusta
# C: Providence
# D: Harrisburg
#
#
# 20) What is the capital of California?
#
# A: Salem
# B: Annapolis
# C: Sacramento
# D: Boston
#
#
# 21) What is the capital of Texas?
#
# A: Austin
# B: Jackson
# C: Topeka
# D: Carson City
#
#
# 22) What is the capital of Alaska?
#
# A: Tallahassee
# B: Augusta
# C: Juneau
# D: Carson City
#
#
# 23) What is the capital of Hawaii?
#
# A: Honolulu
# B: Harrisburg
# C: Cheyenne
# D: Hartford
#
#
# 24) What is the capital of Kansas?
#
# A: Nashville
# B: Raleigh
# C: Topeka
# D: Jackson
#
#
# 25) What is the capital of New Jersey?
#
# A: Helena
# B: Trenton
# C: Austin
# D: Tallahassee
#
#
# 26) What is the capital of Maine?
#
# A: Baton Rouge
# B: Salem
# C: Augusta
# D: Hartford
#
#
# 27) What is the capital of South Carolina?
#
# A: Helena
# B: Albany
# C: Columbia
# D: Tallahassee
#
#
# 28) What is the capital of Washington?
#
# A: Columbus
# B: Atlanta
# C: Olympia
# D: Hartford
#
#
# 29) What is the capital of Ohio?
#
# A: Indianapolis
# B: Helena
# C: Albany
# D: Columbus
#
#
# 30) What is the capital of Massachusetts?
#
# A: Baton Rouge
# B: Boston
# C: Salem
# D: Santa Fe
#
#
# 31) What is the capital of Oregon?
#
# A: Harrisburg
# B: Augusta
# C: Salem
# D: Springfield
#
#
# 32) What is the capital of Arkansas?
#
# A: Atlanta
# B: Little Rock
# C: Salt Lake City
# D: Pierre
#
#
# 33) What is the capital of Illinois?
#
# A: Des Moines
# B: Springfield
# C: Albany
# D: Helena
#
#
# 34) What is the capital of Montana?
#
# A: Baton Rouge
# B: Helena
# C: Sacramento
# D: Frankfort
#
#
# 35) What is the capital of South Dakota?
#
# A: Montgomery
# B: Pierre
# C: Lansing
# D: Frankfort
#
#
# 36) What is the capital of Delaware?
#
# A: Oklahoma City
# B: Des Moines
# C: Dover
# D: Baton Rouge
#
#
# 37) What is the capital of Kentucky?
#
# A: Olympia
# B: Frankfort
# C: Annapolis
# D: Charleston
#
#
# 38) What is the capital of North Dakota?
#
# A: Augusta
# B: Baton Rouge
# C: Frankfort
# D: Bismarck
#
#
# 39) What is the capital of Michigan?
#
# A: Little Rock
# B: Lansing
# C: Oklahoma City
# D: Phoenix
#
#
# 40) What is the capital of Oklahoma?
#
# A: Oklahoma City
# B: Juneau
# C: Topeka
# D: Montpelier
#
#
# 41) What is the capital of Colorado?
#
# A: Madison
# B: Olympia
# C: Oklahoma City
# D: Denver
#
#
# 42) What is the capital of North Carolina?
#
# A: Raleigh
# B: Saint Paul
# C: Columbia
# D: Cheyenne
#
#
# 43) What is the capital of Iowa?
#
# A: Des Moines
# B: Baton Rouge
# C: Santa Fe
# D: Harrisburg
#
#
# 44) What is the capital of New Hampshire?
#
# A: Lansing
# B: Concord
# C: Lincoln
# D: Nashville
#
#
# 45) What is the capital of Nevada?
#
# A: Salt Lake City
# B: Tallahassee
# C: Carson City
# D: Saint Paul
#
#
# 46) What is the capital of Nebraska?
#
# A: Helena
# B: Boston
# C: Richmond
# D: Lincoln
#
#
# 47) What is the capital of New York?
#
# A: Jackson
# B: Albany
# C: Salt Lake City
# D: Raleigh
#
#
# 48) What is the capital of Maryland?
#
# A: Santa Fe
# B: Frankfort
# C: Raleigh
# D: Annapolis
#
#
# 49) What is the capital of Mississippi?
#
# A: Topeka
# B: Pierre
# C: Jackson
# D: Cheyenne
#
#
# 50) What is the capital of New Mexico?
#
# A: Santa Fe
# B: Concord
# C: Indianapolis
# D: Phoenix
#
#
# 1) What is the capital of Delaware?
#
# A: Annapolis
# B: Austin
# C: Dover
# D: Columbia
#
#
# 2) What is the capital of Michigan?
#
# A: Little Rock
# B: Dover
# C: Montpelier
# D: Lansing
#
#
# 3) What is the capital of California?
#
# A: Lincoln
# B: Austin
# C: Boston
# D: Sacramento
#
#
# 4) What is the capital of Wisconsin?
#
# A: Raleigh
# B: Madison
# C: Harrisburg
# D: Trenton
#
#
# 5) What is the capital of Florida?
#
# A: Charleston
# B: Juneau
# C: Tallahassee
# D: Montpelier
#
#
# 6) What is the capital of Iowa?
#
# A: Austin
# B: Des Moines
# C: Richmond
# D: Salem
#
#
# 7) What is the capital of Pennsylvania?
#
# A: Tallahassee
# B: Salem
# C: Bismarck
# D: Harrisburg
#
#
# 8) What is the capital of New Jersey?
#
# A: Austin
# B: Trenton
# C: Olympia
# D: Cheyenne
#
#
# 9) What is the capital of Oklahoma?
#
# A: Oklahoma City
# B: Jackson
# C: Boston
# D: Pierre
#
#
# 10) What is the capital of Ohio?
#
# A: Salem
# B: Oklahoma City
# C: Columbus
# D: Nashville
#
#
# 11) What is the capital of Hawaii?
#
# A: Charleston
# B: Annapolis
# C: Raleigh
# D: Honolulu
#
#
# 12) What is the capital of New Mexico?
#
# A: Santa Fe
# B: Little Rock
# C: Columbus
# D: Baton Rouge
#
#
# 13) What is the capital of Texas?
#
# A: Austin
# B: Oklahoma City
# C: Frankfort
# D: Concord
#
#
# 14) What is the capital of Idaho?
#
# A: Boise
# B: Concord
# C: Providence
# D: Frankfort
#
#
# 15) What is the capital of Tennessee?
#
# A: Madison
# B: Saint Paul
# C: Nashville
# D: Dover
#
#
# 16) What is the capital of South Carolina?
#
# A: Austin
# B: Indianapolis
# C: Columbia
# D: Concord
#
#
# 17) What is the capital of Massachusetts?
#
# A: Montpelier
# B: Frankfort
# C: Lincoln
# D: Boston
#
#
# 18) What is the capital of Wyoming?
#
# A: Santa Fe
# B: Topeka
# C: Raleigh
# D: Cheyenne
#
#
# 19) What is the capital of Maine?
#
# A: Cheyenne
# B: Augusta
# C: Springfield
# D: Montgomery
#
#
# 20) What is the capital of Alaska?
#
# A: Saint Paul
# B: Indianapolis
# C: Juneau
# D: Columbia
#
#
# 21) What is the capital of Minnesota?
#
# A: Phoenix
# B: Honolulu
# C: Saint Paul
# D: Baton Rouge
#
#
# 22) What is the capital of Washington?
#
# A: Frankfort
# B: Salem
# C: Harrisburg
# D: Olympia
#
#
# 23) What is the capital of New York?
#
# A: Jefferson City
# B: Honolulu
# C: Santa Fe
# D: Albany
#
#
# 24) What is the capital of North Carolina?
#
# A: Raleigh
# B: Olympia
# C: Atlanta
# D: Concord
#
#
# 25) What is the capital of Mississippi?
#
# A: Jackson
# B: Little Rock
# C: Phoenix
# D: Montpelier
#
#
# 26) What is the capital of Utah?
#
# A: Salt Lake City
# B: Saint Paul
# C: Augusta
# D: Sacramento
#
#
# 27) What is the capital of Louisiana?
#
# A: Boston
# B: Augusta
# C: Pierre
# D: Baton Rouge
#
#
# 28) What is the capital of Missouri?
#
# A: Jefferson City
# B: Charleston
# C: Helena
# D: Atlanta
#
#
# 29) What is the capital of Rhode Island?
#
# A: Oklahoma City
# B: Providence
# C: Juneau
# D: Augusta
#
#
# 30) What is the capital of Montana?
#
# A: Helena
# B: Jackson
# C: Annapolis
# D: Little Rock
#
#
# 31) What is the capital of Virginia?
#
# A: Nashville
# B: Pierre
# C: Richmond
# D: Augusta
#
#
# 32) What is the capital of Colorado?
#
# A: Jackson
# B: Denver
# C: Jefferson City
# D: Little Rock
#
#
# 33) What is the capital of Georgia?
#
# A: Atlanta
# B: Hartford
# C: Little Rock
# D: Jackson
#
#
# 34) What is the capital of Arizona?
#
# A: Augusta
# B: Cheyenne
# C: Salem
# D: Phoenix
#
#
# 35) What is the capital of New Hampshire?
#
# A: Concord
# B: Bismarck
# C: Springfield
# D: Lansing
#
#
# 36) What is the capital of Kentucky?
#
# A: Baton Rouge
# B: Frankfort
# C: Charleston
# D: Austin
#
#
# 37) What is the capital of West Virginia?
#
# A: Augusta
# B: Boise
# C: Jefferson City
# D: Charleston
#
#
# 38) What is the capital of Indiana?
#
# A: Columbia
# B: Indianapolis
# C: Tallahassee
# D: Santa Fe
#
#
# 39) What is the capital of Nevada?
#
# A: Jackson
# B: Carson City
# C: Trenton
# D: Baton Rouge
#
#
# 40) What is the capital of North Dakota?
#
# A: Bismarck
# B: Trenton
# C: Saint Paul
# D: Little Rock
#
#
# 41) What is the capital of Connecticut?
#
# A: Saint Paul
# B: Hartford
# C: Salem
# D: Carson City
#
#
# 42) What is the capital of Kansas?
#
# A: Saint Paul
# B: Topeka
# C: Montpelier
# D: Cheyenne
#
#
# 43) What is the capital of Maryland?
#
# A: Nashville
# B: Columbus
# C: Boston
# D: Annapolis
#
#
# 44) What is the capital of Vermont?
#
# A: Austin
# B: Columbia
# C: Montpelier
# D: Nashville
#
#
# 45) What is the capital of Alabama?
#
# A: Lansing
# B: Tallahassee
# C: Boise
# D: Montgomery
#
#
# 46) What is the capital of Oregon?
#
# A: Boise
# B: Tallahassee
# C: Salem
# D: Hartford
#
#
# 47) What is the capital of Nebraska?
#
# A: Boston
# B: Denver
# C: Raleigh
# D: Lincoln
#
#
# 48) What is the capital of Illinois?
#
# A: Little Rock
# B: Springfield
# C: Oklahoma City
# D: Des Moines
#
#
# 49) What is the capital of Arkansas?
#
# A: Little Rock
# B: Columbia
# C: Boise
# D: Indianapolis
#
#
# 50) What is the capital of South Dakota?
#
# A: Des Moines
# B: Tallahassee
# C: Pierre
# D: Jefferson City
#
#
# 1) What is the capital of Oklahoma?
#
# A: Bismarck
# B: Sacramento
# C: Jefferson City
# D: Oklahoma City
#
#
# 2) What is the capital of Wisconsin?
#
# A: Madison
# B: Harrisburg
# C: Sacramento
# D: Annapolis
#
#
# 3) What is the capital of New Jersey?
#
# A: Lansing
# B: Trenton
# C: Olympia
# D: Santa Fe
#
#
# 4) What is the capital of Vermont?
#
# A: Helena
# B: Columbia
# C: Springfield
# D: Montpelier
#
#
# 5) What is the capital of Texas?
#
# A: Juneau
# B: Austin
# C: Lansing
# D: Baton Rouge
#
#
# 6) What is the capital of Nebraska?
#
# A: Saint Paul
# B: Indianapolis
# C: Cheyenne
# D: Lincoln
#
#
# 7) What is the capital of Alaska?
#
# A: Atlanta
# B: Augusta
# C: Juneau
# D: Lansing
#
#
# 8) What is the capital of Idaho?
#
# A: Columbus
# B: Boise
# C: Augusta
# D: Nashville
#
#
# 9) What is the capital of North Dakota?
#
# A: Concord
# B: Bismarck
# C: Denver
# D: Pierre
#
#
# 10) What is the capital of Michigan?
#
# A: Lansing
# B: Lincoln
# C: Phoenix
# D: Madison
#
#
# 11) What is the capital of Virginia?
#
# A: Boston
# B: Richmond
# C: Concord
# D: Honolulu
#
#
# 12) What is the capital of Arizona?
#
# A: Madison
# B: Phoenix
# C: Olympia
# D: Saint Paul
#
#
# 13) What is the capital of Delaware?
#
# A: Montgomery
# B: Little Rock
# C: Bismarck
# D: Dover
#
#
# 14) What is the capital of Nevada?
#
# A: Carson City
# B: Hartford
# C: Columbia
# D: Lincoln
#
#
# 15) What is the capital of Maryland?
#
# A: Oklahoma City
# B: Baton Rouge
# C: Annapolis
# D: Augusta
#
#
# 16) What is the capital of West Virginia?
#
# A: Annapolis
# B: Charleston
# C: Pierre
# D: Oklahoma City
#
#
# 17) What is the capital of Iowa?
#
# A: Lansing
# B: Hartford
# C: Honolulu
# D: Des Moines
#
#
# 18) What is the capital of Illinois?
#
# A: Charleston
# B: Harrisburg
# C: Springfield
# D: Lincoln
#
#
# 19) What is the capital of Oregon?
#
# A: Frankfort
# B: Salem
# C: Pierre
# D: Providence
#
#
# 20) What is the capital of Massachusetts?
#
# A: Springfield
# B: Boston
# C: Trenton
# D: Pierre
#
#
# 21) What is the capital of Pennsylvania?
#
# A: Columbia
# B: Oklahoma City
# C: Harrisburg
# D: Jackson
#
#
# 22) What is the capital of Utah?
#
# A: Frankfort
# B: Honolulu
# C: Salt Lake City
# D: Salem
#
#
# 23) What is the capital of Florida?
#
# A: Tallahassee
# B: Richmond
# C: Boston
# D: Austin
#
#
# 24) What is the capital of Washington?
#
# A: Montgomery
# B: Olympia
# C: Richmond
# D: Frankfort
#
#
# 25) What is the capital of Minnesota?
#
# A: Saint Paul
# B: Salem
# C: Little Rock
# D: Carson City
#
#
# 26) What is the capital of Mississippi?
#
# A: Jackson
# B: Saint Paul
# C: Lincoln
# D: Tallahassee
#
#
# 27) What is the capital of Kentucky?
#
# A: Santa Fe
# B: Richmond
# C: Charleston
# D: Frankfort
#
#
# 28) What is the capital of Georgia?
#
# A: Pierre
# B: Atlanta
# C: Baton Rouge
# D: Sacramento
#
#
# 29) What is the capital of Louisiana?
#
# A: Baton Rouge
# B: Sacramento
# C: Little Rock
# D: Carson City
#
#
# 30) What is the capital of New York?
#
# A: Albany
# B: Tallahassee
# C: Austin
# D: Salem
#
#
# 31) What is the capital of Connecticut?
#
# A: Juneau
# B: Salt Lake City
# C: Hartford
# D: Madison
#
#
# 32) What is the capital of Ohio?
#
# A: Columbus
# B: Denver
# C: Boise
# D: Olympia
#
#
# 33) What is the capital of Alabama?
#
# A: Trenton
# B: Des Moines
# C: Baton Rouge
# D: Montgomery
#
#
# 34) What is the capital of Rhode Island?
#
# A: Austin
# B: Santa Fe
# C: Providence
# D: Harrisburg
#
#
# 35) What is the capital of Tennessee?
#
# A: Lansing
# B: Nashville
# C: Honolulu
# D: Dover
#
#
# 36) What is the capital of Missouri?
#
# A: Charleston
# B: Tallahassee
# C: Salem
# D: Jefferson City
#
#
# 37) What is the capital of New Hampshire?
#
# A: Saint Paul
# B: Columbia
# C: Frankfort
# D: Concord
#
#
# 38) What is the capital of South Carolina?
#
# A: Baton Rouge
# B: Columbia
# C: Dover
# D: Helena
#
#
# 39) What is the capital of South Dakota?
#
# A: Phoenix
# B: Columbus
# C: Santa Fe
# D: Pierre
#
#
# 40) What is the capital of Colorado?
#
# A: Frankfort
# B: Denver
# C: Jackson
# D: Dover
#
#
# 41) What is the capital of Wyoming?
#
# A: Concord
# B: Frankfort
# C: Cheyenne
# D: Montpelier
#
#
# 42) What is the capital of Maine?
#
# A: Harrisburg
# B: Bismarck
# C: Salt Lake City
# D: Augusta
#
#
# 43) What is the capital of Montana?
#
# A: Helena
# B: Jackson
# C: Madison
# D: Annapolis
#
#
# 44) What is the capital of Indiana?
#
# A: Lincoln
# B: Albany
# C: Annapolis
# D: Indianapolis
#
#
# 45) What is the capital of North Carolina?
#
# A: Phoenix
# B: Raleigh
# C: Saint Paul
# D: Olympia
#
#
# 46) What is the capital of New Mexico?
#
# A: Phoenix
# B: Santa Fe
# C: Concord
# D: Indianapolis
#
#
# 47) What is the capital of California?
#
# A: Sacramento
# B: Trenton
# C: Little Rock
# D: Charleston
#
#
# 48) What is the capital of Arkansas?
#
# A: Little Rock
# B: Helena
# C: Columbus
# D: Baton Rouge
#
#
# 49) What is the capital of Kansas?
#
# A: Charleston
# B: Topeka
# C: Honolulu
# D: Lincoln
#
#
# 50) What is the capital of Hawaii?
#
# A: Madison
# B: Honolulu
# C: Jackson
# D: Santa Fe
#
#
# 1) What is the capital of Virginia?
#
# A: Austin
# B: Trenton
# C: Frankfort
# D: Richmond
#
#
# 2) What is the capital of Pennsylvania?
#
# A: Lincoln
# B: Tallahassee
# C: Harrisburg
# D: Montgomery
#
#
# 3) What is the capital of Wisconsin?
#
# A: Madison
# B: Lansing
# C: Baton Rouge
# D: Honolulu
#
#
# 4) What is the capital of Iowa?
#
# A: Des Moines
# B: Columbia
# C: Helena
# D: Saint Paul
#
#
# 5) What is the capital of Nevada?
#
# A: Carson City
# B: Little Rock
# C: Salem
# D: Springfield
#
#
# 6) What is the capital of New Jersey?
#
# A: Denver
# B: Jackson
# C: Des Moines
# D: Trenton
#
#
# 7) What is the capital of Indiana?
#
# A: Frankfort
# B: Raleigh
# C: Springfield
# D: Indianapolis
#
#
# 8) What is the capital of Illinois?
#
# A: Springfield
# B: Olympia
# C: Hartford
# D: Baton Rouge
#
#
# 9) What is the capital of Mississippi?
#
# A: Boise
# B: Saint Paul
# C: Denver
# D: Jackson
#
#
# 10) What is the capital of North Carolina?
#
# A: Augusta
# B: Raleigh
# C: Lansing
# D: Charleston
#
#
# 11) What is the capital of Colorado?
#
# A: Denver
# B: Austin
# C: Juneau
# D: Trenton
#
#
# 12) What is the capital of Massachusetts?
#
# A: Jackson
# B: Madison
# C: Phoenix
# D: Boston
#
#
# 13) What is the capital of Michigan?
#
# A: Lansing
# B: Springfield
# C: Honolulu
# D: Jackson
#
#
# 14) What is the capital of Delaware?
#
# A: Baton Rouge
# B: Dover
# C: Salt Lake City
# D: Atlanta
#
#
# 15) What is the capital of Oklahoma?
#
# A: Madison
# B: Oklahoma City
# C: Honolulu
# D: Des Moines
#
#
# 16) What is the capital of Arkansas?
#
# A: Little Rock
# B: Albany
# C: Concord
# D: Harrisburg
#
#
# 17) What is the capital of California?
#
# A: Sacramento
# B: Annapolis
# C: Montgomery
# D: Indianapolis
#
#
# 18) What is the capital of Georgia?
#
# A: Richmond
# B: Austin
# C: Cheyenne
# D: Atlanta
#
#
# 19) What is the capital of South Carolina?
#
# A: Concord
# B: Sacramento
# C: Columbia
# D: Oklahoma City
#
#
# 20) What is the capital of Idaho?
#
# A: Boise
# B: Atlanta
# C: Augusta
# D: Tallahassee
#
#
# 21) What is the capital of Minnesota?
#
# A: Saint Paul
# B: Baton Rouge
# C: Columbia
# D: Phoenix
#
#
# 22) What is the capital of Alaska?
#
# A: Frankfort
# B: Juneau
# C: Nashville
# D: Augusta
#
#
# 23) What is the capital of Utah?
#
# A: Annapolis
# B: Atlanta
# C: Salt Lake City
# D: Honolulu
#
#
# 24) What is the capital of Texas?
#
# A: Columbia
# B: Frankfort
# C: Austin
# D: Augusta
#
#
# 25) What is the capital of Washington?
#
# A: Olympia
# B: Cheyenne
# C: Des Moines
# D: Bismarck
#
#
# 26) What is the capital of New Mexico?
#
# A: Santa Fe
# B: Charleston
# C: Montpelier
# D: Denver
#
#
# 27) What is the capital of Oregon?
#
# A: Albany
# B: Salem
# C: Honolulu
# D: Columbus
#
#
# 28) What is the capital of Connecticut?
#
# A: Columbia
# B: Hartford
# C: Denver
# D: Columbus
#
#
# 29) What is the capital of Nebraska?
#
# A: Indianapolis
# B: Montgomery
# C: Lincoln
# D: Richmond
#
#
# 30) What is the capital of West Virginia?
#
# A: Des Moines
# B: Carson City
# C: Hartford
# D: Charleston
#
#
# 31) What is the capital of New York?
#
# A: Boise
# B: Charleston
# C: Albany
# D: Jefferson City
#
#
# 32) What is the capital of Louisiana?
#
# A: Nashville
# B: Olympia
# C: Bismarck
# D: Baton Rouge
#
#
# 33) What is the capital of Tennessee?
#
# A: Nashville
# B: Albany
# C: Richmond
# D: Oklahoma City
#
#
# 34) What is the capital of Kentucky?
#
# A: Topeka
# B: Jefferson City
# C: Indianapolis
# D: Frankfort
#
#
# 35) What is the capital of Ohio?
#
# A: Jefferson City
# B: Annapolis
# C: Baton Rouge
# D: Columbus
#
#
# 36) What is the capital of Maryland?
#
# A: Montgomery
# B: Concord
# C: Raleigh
# D: Annapolis
#
#
# 37) What is the capital of Alabama?
#
# A: Montgomery
# B: Austin
# C: Raleigh
# D: Tallahassee
#
#
# 38) What is the capital of Rhode Island?
#
# A: Albany
# B: Bismarck
# C: Providence
# D: Salt Lake City
#
#
# 39) What is the capital of Missouri?
#
# A: Austin
# B: Des Moines
# C: Denver
# D: Jefferson City
#
#
# 40) What is the capital of Hawaii?
#
# A: Honolulu
# B: Hartford
# C: Little Rock
# D: Columbus
#
#
# 41) What is the capital of Kansas?
#
# A: Topeka
# B: Honolulu
# C: Helena
# D: Lincoln
#
#
# 42) What is the capital of Wyoming?
#
# A: Cheyenne
# B: Hartford
# C: Richmond
# D: Lansing
#
#
# 43) What is the capital of Vermont?
#
# A: Indianapolis
# B: Springfield
# C: Montpelier
# D: Denver
#
#
# 44) What is the capital of South Dakota?
#
# A: Pierre
# B: Topeka
# C: Denver
# D: Sacramento
#
#
# 45) What is the capital of North Dakota?
#
# A: Boise
# B: Lincoln
# C: Springfield
# D: Bismarck
#
#
# 46) What is the capital of Montana?
#
# A: Helena
# B: Montpelier
# C: Albany
# D: Olympia
#
#
# 47) What is the capital of New Hampshire?
#
# A: Salem
# B: Atlanta
# C: Concord
# D: Bismarck
#
#
# 48) What is the capital of Florida?
#
# A: Dover
# B: Tallahassee
# C: Springfield
# D: Charleston
#
#
# 49) What is the capital of Maine?
#
# A: Lansing
# B: Madison
# C: Little Rock
# D: Augusta
#
#
# 50) What is the capital of Arizona?
#
# A: Columbia
# B: Harrisburg
# C: Phoenix
# D: Providence
#
#
# 1) What is the capital of New Mexico?
#
# A: Springfield
# B: Santa Fe
# C: Salem
# D: Harrisburg
#
#
# 2) What is the capital of Wyoming?
#
# A: Lincoln
# B: Albany
# C: Jackson
# D: Cheyenne
#
#
# 3) What is the capital of North Dakota?
#
# A: Bismarck
# B: Salem
# C: Boston
# D: Indianapolis
#
#
# 4) What is the capital of Vermont?
#
# A: Saint Paul
# B: Montpelier
# C: Honolulu
# D: Harrisburg
#
#
# 5) What is the capital of Oklahoma?
#
# A: Madison
# B: Oklahoma City
# C: Indianapolis
# D: Denver
#
#
# 6) What is the capital of Washington?
#
# A: Dover
# B: Lincoln
# C: Olympia
# D: Richmond
#
#
# 7) What is the capital of Michigan?
#
# A: Annapolis
# B: Columbia
# C: Lansing
# D: Augusta
#
#
# 8) What is the capital of Georgia?
#
# A: Atlanta
# B: Hartford
# C: Harrisburg
# D: Columbus
#
#
# 9) What is the capital of Ohio?
#
# A: Salt Lake City
# B: Columbus
# C: Baton Rouge
# D: Albany
#
#
# 10) What is the capital of Tennessee?
#
# A: Nashville
# B: Dover
# C: Sacramento
# D: Baton Rouge
#
#
# 11) What is the capital of Illinois?
#
# A: Topeka
# B: Springfield
# C: Harrisburg
# D: Boise
#
#
# 12) What is the capital of Nebraska?
#
# A: Lincoln
# B: Frankfort
# C: Olympia
# D: Austin
#
#
# 13) What is the capital of New Jersey?
#
# A: Austin
# B: Bismarck
# C: Harrisburg
# D: Trenton
#
#
# 14) What is the capital of Alabama?
#
# A: Frankfort
# B: Albany
# C: Madison
# D: Montgomery
#
#
# 15) What is the capital of Virginia?
#
# A: Augusta
# B: Richmond
# C: Austin
# D: Topeka
#
#
# 16) What is the capital of Rhode Island?
#
# A: Charleston
# B: Providence
# C: Dover
# D: Cheyenne
#
#
# 17) What is the capital of Oregon?
#
# A: Saint Paul
# B: Salt Lake City
# C: Salem
# D: Providence
#
#
# 18) What is the capital of Montana?
#
# A: Helena
# B: Trenton
# C: Montpelier
# D: Phoenix
#
#
# 19) What is the capital of Arkansas?
#
# A: Little Rock
# B: Charleston
# C: Topeka
# D: Frankfort
#
#
# 20) What is the capital of Colorado?
#
# A: Denver
# B: Annapolis
# C: Bismarck
# D: Lansing
#
#
# 21) What is the capital of Kansas?
#
# A: Pierre
# B: Saint Paul
# C: Trenton
# D: Topeka
#
#
# 22) What is the capital of Mississippi?
#
# A: Jackson
# B: Austin
# C: Salt Lake City
# D: Columbus
#
#
# 23) What is the capital of Texas?
#
# A: Saint Paul
# B: Austin
# C: Dover
# D: Springfield
#
#
# 24) What is the capital of New Hampshire?
#
# A: Concord
# B: Madison
# C: Baton Rouge
# D: Jackson
#
#
# 25) What is the capital of Connecticut?
#
# A: Concord
# B: Hartford
# C: Carson City
# D: Lansing
#
#
# 26) What is the capital of Utah?
#
# A: Concord
# B: Austin
# C: Annapolis
# D: Salt Lake City
#
#
# 27) What is the capital of Arizona?
#
# A: Columbus
# B: Phoenix
# C: Saint Paul
# D: Austin
#
#
# 28) What is the capital of Nevada?
#
# A: Lansing
# B: Harrisburg
# C: Bismarck
# D: Carson City
#
#
# 29) What is the capital of Alaska?
#
# A: Juneau
# B: Annapolis
# C: Albany
# D: Olympia
#
#
# 30) What is the capital of Maine?
#
# A: Augusta
# B: Springfield
# C: Jackson
# D: Charleston
#
#
# 31) What is the capital of Iowa?
#
# A: Richmond
# B: Denver
# C: Baton Rouge
# D: Des Moines
#
#
# 32) What is the capital of Louisiana?
#
# A: Baton Rouge
# B: Boston
# C: Santa Fe
# D: Nashville
#
#
# 33) What is the capital of New York?
#
# A: Atlanta
# B: Albany
# C: Tallahassee
# D: Montpelier
#
#
# 34) What is the capital of Hawaii?
#
# A: Honolulu
# B: Frankfort
# C: Providence
# D: Juneau
#
#
# 35) What is the capital of North Carolina?
#
# A: Boston
# B: Hartford
# C: Raleigh
# D: Frankfort
#
#
# 36) What is the capital of West Virginia?
#
# A: Charleston
# B: Boston
# C: Lansing
# D: Topeka
#
#
# 37) What is the capital of Kentucky?
#
# A: Albany
# B: Frankfort
# C: Topeka
# D: Baton Rouge
#
#
# 38) What is the capital of Indiana?
#
# A: Indianapolis
# B: Albany
# C: Des Moines
# D: Montpelier
#
#
# 39) What is the capital of South Carolina?
#
# A: Providence
# B: Columbia
# C: Boston
# D: Madison
#
#
# 40) What is the capital of Pennsylvania?
#
# A: Des Moines
# B: Lincoln
# C: Harrisburg
# D: Phoenix
#
#
# 41) What is the capital of Maryland?
#
# A: Indianapolis
# B: Springfield
# C: Santa Fe
# D: Annapolis
#
#
# 42) What is the capital of Delaware?
#
# A: Sacramento
# B: Montpelier
# C: Honolulu
# D: Dover
#
#
# 43) What is the capital of Idaho?
#
# A: Bismarck
# B: Salt Lake City
# C: Juneau
# D: Boise
#
#
# 44) What is the capital of Minnesota?
#
# A: Harrisburg
# B: Saint Paul
# C: Montpelier
# D: Jefferson City
#
#
# 45) What is the capital of Missouri?
#
# A: Olympia
# B: Trenton
# C: Jefferson City
# D: Annapolis
#
#
# 46) What is the capital of Wisconsin?
#
# A: Phoenix
# B: Frankfort
# C: Helena
# D: Madison
#
#
# 47) What is the capital of Florida?
#
# A: Tallahassee
# B: Richmond
# C: Phoenix
# D: Juneau
#
#
# 48) What is the capital of California?
#
# A: Boston
# B: Boise
# C: Sacramento
# D: Trenton
#
#
# 49) What is the capital of Massachusetts?
#
# A: Boston
# B: Concord
# C: Montgomery
# D: Dover
#
#
# 50) What is the capital of South Dakota?
#
# A: Phoenix
# B: Montpelier
# C: Madison
# D: Pierre
#
#
# 1) What is the capital of Delaware?
#
# A: Dover
# B: Augusta
# C: Little Rock
# D: Columbus
#
#
# 2) What is the capital of Arkansas?
#
# A: Trenton
# B: Santa Fe
# C: Little Rock
# D: Phoenix
#
#
# 3) What is the capital of Idaho?
#
# A: Boise
# B: Hartford
# C: Pierre
# D: Sacramento
#
#
# 4) What is the capital of Alabama?
#
# A: Springfield
# B: Montgomery
# C: Des Moines
# D: Dover
#
#
# 5) What is the capital of California?
#
# A: Raleigh
# B: Trenton
# C: Sacramento
# D: Harrisburg
#
#
# 6) What is the capital of New Mexico?
#
# A: Boise
# B: Indianapolis
# C: Santa Fe
# D: Trenton
#
#
# 7) What is the capital of Oklahoma?
#
# A: Boston
# B: Pierre
# C: Annapolis
# D: Oklahoma City
#
#
# 8) What is the capital of Minnesota?
#
# A: Austin
# B: Columbia
# C: Honolulu
# D: Saint Paul
#
#
# 9) What is the capital of Nebraska?
#
# A: Raleigh
# B: Frankfort
# C: Jackson
# D: Lincoln
#
#
# 10) What is the capital of Indiana?
#
# A: Madison
# B: Indianapolis
# C: Boston
# D: Salt Lake City
#
#
# 11) What is the capital of Nevada?
#
# A: Little Rock
# B: Hartford
# C: Carson City
# D: Albany
#
#
# 12) What is the capital of Montana?
#
# A: Helena
# B: Saint Paul
# C: Columbia
# D: Concord
#
#
# 13) What is the capital of North Carolina?
#
# A: Phoenix
# B: Indianapolis
# C: Raleigh
# D: Helena
#
#
# 14) What is the capital of South Carolina?
#
# A: Olympia
# B: Boise
# C: Albany
# D: Columbia
#
#
# 15) What is the capital of Washington?
#
# A: Cheyenne
# B: Columbus
# C: Olympia
# D: Augusta
#
#
# 16) What is the capital of Missouri?
#
# A: Des Moines
# B: Jefferson City
# C: Albany
# D: Austin
#
#
# 17) What is the capital of Michigan?
#
# A: Lansing
# B: Boise
# C: Charleston
# D: Columbus
#
#
# 18) What is the capital of Louisiana?
#
# A: Carson City
# B: Baton Rouge
# C: Juneau
# D: Little Rock
#
#
# 19) What is the capital of Vermont?
#
# A: Montpelier
# B: Concord
# C: Pierre
# D: Cheyenne
#
#
# 20) What is the capital of Wisconsin?
#
# A: Topeka
# B: Dover
# C: Nashville
# D: Madison
#
#
# 21) What is the capital of Pennsylvania?
#
# A: Harrisburg
# B: Augusta
# C: Carson City
# D: Salem
#
#
# 22) What is the capital of Florida?
#
# A: Tallahassee
# B: Concord
# C: Madison
# D: Carson City
#
#
# 23) What is the capital of Illinois?
#
# A: Denver
# B: Honolulu
# C: Pierre
# D: Springfield
#
#
# 24) What is the capital of Alaska?
#
# A: Harrisburg
# B: Juneau
# C: Annapolis
# D: Denver
#
#
# 25) What is the capital of Utah?
#
# A: Little Rock
# B: Atlanta
# C: Sacramento
# D: Salt Lake City
#
#
# 26) What is the capital of Tennessee?
#
# A: Montgomery
# B: Albany
# C: Nashville
# D: Pierre
#
#
# 27) What is the capital of Maryland?
#
# A: Oklahoma City
# B: Denver
# C: Annapolis
# D: Bismarck
#
#
# 28) What is the capital of New York?
#
# A: Charleston
# B: Albany
# C: Jackson
# D: Denver
#
#
# 29) What is the capital of New Hampshire?
#
# A: Concord
# B: Olympia
# C: Bismarck
# D: Indianapolis
#
#
# 30) What is the capital of Wyoming?
#
# A: Columbus
# B: Dover
# C: Charleston
# D: Cheyenne
#
#
# 31) What is the capital of Oregon?
#
# A: Raleigh
# B: Salem
# C: Hartford
# D: Indianapolis
#
#
# 32) What is the capital of New Jersey?
#
# A: Indianapolis
# B: Trenton
# C: Frankfort
# D: Olympia
#
#
# 33) What is the capital of Mississippi?
#
# A: Pierre
# B: Montpelier
# C: Boston
# D: Jackson
#
#
# 34) What is the capital of Rhode Island?
#
# A: Providence
# B: Frankfort
# C: Dover
# D: Hartford
#
#
# 35) What is the capital of Virginia?
#
# A: Pierre
# B: Richmond
# C: Dover
# D: Trenton
#
#
# 36) What is the capital of Maine?
#
# A: Augusta
# B: Providence
# C: Helena
# D: Harrisburg
#
#
# 37) What is the capital of Iowa?
#
# A: Jackson
# B: Phoenix
# C: Des Moines
# D: Salem
#
#
# 38) What is the capital of Kansas?
#
# A: Helena
# B: Columbus
# C: Topeka
# D: Salem
#
#
# 39) What is the capital of Arizona?
#
# A: Richmond
# B: Topeka
# C: Frankfort
# D: Phoenix
#
#
# 40) What is the capital of Colorado?
#
# A: Santa Fe
# B: Springfield
# C: Denver
# D: Des Moines
#
#
# 41) What is the capital of Texas?
#
# A: Austin
# B: Honolulu
# C: Madison
# D: Harrisburg
#
#
# 42) What is the capital of South Dakota?
#
# A: Helena
# B: Denver
# C: Pierre
# D: Cheyenne
#
#
# 43) What is the capital of Massachusetts?
#
# A: Boston
# B: Providence
# C: Frankfort
# D: Montpelier
#
#
# 44) What is the capital of Ohio?
#
# A: Columbus
# B: Oklahoma City
# C: Frankfort
# D: Juneau
#
#
# 45) What is the capital of North Dakota?
#
# A: Bismarck
# B: Hartford
# C: Sacramento
# D: Pierre
#
#
# 46) What is the capital of Kentucky?
#
# A: Tallahassee
# B: Frankfort
# C: Albany
# D: Saint Paul
#
#
# 47) What is the capital of Hawaii?
#
# A: Hartford
# B: Harrisburg
# C: Concord
# D: Honolulu
#
#
# 48) What is the capital of Connecticut?
#
# A: Helena
# B: Phoenix
# C: Trenton
# D: Hartford
#
#
# 49) What is the capital of Georgia?
#
# A: Springfield
# B: Atlanta
# C: Santa Fe
# D: Cheyenne
#
#
# 50) What is the capital of West Virginia?
#
# A: Charleston
# B: Lincoln
# C: Harrisburg
# D: Santa Fe
#
#
# 1) What is the capital of New Jersey?
#
# A: Carson City
# B: Trenton
# C: Richmond
# D: Cheyenne
#
#
# 2) What is the capital of Iowa?
#
# A: Des Moines
# B: Columbus
# C: Raleigh
# D: Cheyenne
#
#
# 3) What is the capital of Arizona?
#
# A: Albany
# B: Indianapolis
# C: Pierre
# D: Phoenix
#
#
# 4) What is the capital of Rhode Island?
#
# A: Providence
# B: Carson City
# C: Nashville
# D: Pierre
#
#
# 5) What is the capital of Kansas?
#
# A: Topeka
# B: Dover
# C: Pierre
# D: Montpelier
#
#
# 6) What is the capital of Alaska?
#
# A: Nashville
# B: Montgomery
# C: Juneau
# D: Jackson
#
#
# 7) What is the capital of Tennessee?
#
# A: Richmond
# B: Pierre
# C: Nashville
# D: Raleigh
#
#
# 8) What is the capital of Wisconsin?
#
# A: Lincoln
# B: Springfield
# C: Madison
# D: Atlanta
#
#
# 9) What is the capital of Texas?
#
# A: Boise
# B: Hartford
# C: Columbus
# D: Austin
#
#
# 10) What is the capital of Montana?
#
# A: Sacramento
# B: Bismarck
# C: Topeka
# D: Helena
#
#
# 11) What is the capital of Washington?
#
# A: Olympia
# B: Richmond
# C: Carson City
# D: Oklahoma City
#
#
# 12) What is the capital of Idaho?
#
# A: Boise
# B: Little Rock
# C: Lincoln
# D: Nashville
#
#
# 13) What is the capital of Hawaii?
#
# A: Atlanta
# B: Cheyenne
# C: Honolulu
# D: Lansing
#
#
# 14) What is the capital of Alabama?
#
# A: Sacramento
# B: Montgomery
# C: Jackson
# D: Salem
#
#
# 15) What is the capital of Arkansas?
#
# A: Austin
# B: Little Rock
# C: Pierre
# D: Sacramento
#
#
# 16) What is the capital of Indiana?
#
# A: Jefferson City
# B: Indianapolis
# C: Des Moines
# D: Columbia
#
#
# 17) What is the capital of New York?
#
# A: Montpelier
# B: Jefferson City
# C: Albany
# D: Indianapolis
#
#
# 18) What is the capital of Nevada?
#
# A: Jefferson City
# B: Phoenix
# C: Atlanta
# D: Carson City
#
#
# 19) What is the capital of Utah?
#
# A: Frankfort
# B: Tallahassee
# C: Salt Lake City
# D: Denver
#
#
# 20) What is the capital of Pennsylvania?
#
# A: Hartford
# B: Jackson
# C: Charleston
# D: Harrisburg
#
#
# 21) What is the capital of Massachusetts?
#
# A: Denver
# B: Boston
# C: Richmond
# D: Honolulu
#
#
# 22) What is the capital of Delaware?
#
# A: Topeka
# B: Dover
# C: Saint Paul
# D: Olympia
#
#
# 23) What is the capital of West Virginia?
#
# A: Montpelier
# B: Charleston
# C: Columbus
# D: Montgomery
#
#
# 24) What is the capital of Georgia?
#
# A: Des Moines
# B: Atlanta
# C: Sacramento
# D: Honolulu
#
#
# 25) What is the capital of California?
#
# A: Montgomery
# B: Harrisburg
# C: Sacramento
# D: Carson City
#
#
# 26) What is the capital of Maryland?
#
# A: Lansing
# B: Annapolis
# C: Charleston
# D: Olympia
#
#
# 27) What is the capital of Missouri?
#
# A: Austin
# B: Jefferson City
# C: Frankfort
# D: Saint Paul
#
#
# 28) What is the capital of North Dakota?
#
# A: Trenton
# B: Boston
# C: Denver
# D: Bismarck
#
#
# 29) What is the capital of Kentucky?
#
# A: Columbia
# B: Concord
# C: Frankfort
# D: Montgomery
#
#
# 30) What is the capital of Mississippi?
#
# A: Topeka
# B: Jackson
# C: Atlanta
# D: Baton Rouge
#
#
# 31) What is the capital of Louisiana?
#
# A: Santa Fe
# B: Denver
# C: Des Moines
# D: Baton Rouge
#
#
# 32) What is the capital of Florida?
#
# A: Providence
# B: Boston
# C: Tallahassee
# D: Charleston
#
#
# 33) What is the capital of Vermont?
#
# A: Montpelier
# B: Hartford
# C: Providence
# D: Pierre
#
#
# 34) What is the capital of Illinois?
#
# A: Hartford
# B: Saint Paul
# C: Pierre
# D: Springfield
#
#
# 35) What is the capital of New Mexico?
#
# A: Trenton
# B: Olympia
# C: Augusta
# D: Santa Fe
#
#
# 36) What is the capital of Virginia?
#
# A: Tallahassee
# B: Albany
# C: Richmond
# D: Pierre
#
#
# 37) What is the capital of Michigan?
#
# A: Trenton
# B: Augusta
# C: Bismarck
# D: Lansing
#
#
# 38) What is the capital of Oregon?
#
# A: Nashville
# B: Bismarck
# C: Salem
# D: Lincoln
#
#
# 39) What is the capital of Oklahoma?
#
# A: Harrisburg
# B: Phoenix
# C: Jefferson City
# D: Oklahoma City
#
#
# 40) What is the capital of Nebraska?
#
# A: Pierre
# B: Lincoln
# C: Trenton
# D: Saint Paul
#
#
# 41) What is the capital of New Hampshire?
#
# A: Concord
# B: Bismarck
# C: Helena
# D: Des Moines
#
#
# 42) What is the capital of South Dakota?
#
# A: Providence
# B: Pierre
# C: Springfield
# D: Honolulu
#
#
# 43) What is the capital of Connecticut?
#
# A: Baton Rouge
# B: Richmond
# C: Sacramento
# D: Hartford
#
#
# 44) What is the capital of South Carolina?
#
# A: Albany
# B: Concord
# C: Columbia
# D: Topeka
#
#
# 45) What is the capital of Wyoming?
#
# A: Salem
# B: Cheyenne
# C: Honolulu
# D: Bismarck
#
#
# 46) What is the capital of Maine?
#
# A: Augusta
# B: Frankfort
# C: Columbia
# D: Montgomery
#
#
# 47) What is the capital of North Carolina?
#
# A: Sacramento
# B: Santa Fe
# C: Pierre
# D: Raleigh
#
#
# 48) What is the capital of Ohio?
#
# A: Sacramento
# B: Columbus
# C: Honolulu
# D: Topeka
#
#
# 49) What is the capital of Minnesota?
#
# A: Olympia
# B: Concord
# C: Saint Paul
# D: Little Rock
#
#
# 50) What is the capital of Colorado?
#
# A: Denver
# B: Columbus
# C: Baton Rouge
# D: Pierre
#
#
# 1) What is the capital of Florida?
#
# A: Tallahassee
# B: Olympia
# C: Phoenix
# D: Dover
#
#
# 2) What is the capital of Maine?
#
# A: Austin
# B: Juneau
# C: Augusta
# D: Lansing
#
#
# 3) What is the capital of Utah?
#
# A: Little Rock
# B: Cheyenne
# C: Saint Paul
# D: Salt Lake City
#
#
# 4) What is the capital of South Carolina?
#
# A: Santa Fe
# B: Bismarck
# C: Denver
# D: Columbia
#
#
# 5) What is the capital of Vermont?
#
# A: Raleigh
# B: Montpelier
# C: Salem
# D: Helena
#
#
# 6) What is the capital of South Dakota?
#
# A: Phoenix
# B: Pierre
# C: Richmond
# D: Cheyenne
#
#
# 7) What is the capital of Nebraska?
#
# A: Lincoln
# B: Juneau
# C: Sacramento
# D: Dover
#
#
# 8) What is the capital of Massachusetts?
#
# A: Carson City
# B: Boston
# C: Pierre
# D: Frankfort
#
#
# 9) What is the capital of Maryland?
#
# A: Saint Paul
# B: Tallahassee
# C: Albany
# D: Annapolis
#
#
# 10) What is the capital of Wyoming?
#
# A: Montpelier
# B: Cheyenne
# C: Salem
# D: Montgomery
#
#
# 11) What is the capital of Colorado?
#
# A: Denver
# B: Des Moines
# C: Salem
# D: Augusta
#
#
# 12) What is the capital of Texas?
#
# A: Austin
# B: Nashville
# C: Honolulu
# D: Lincoln
#
#
# 13) What is the capital of Nevada?
#
# A: Carson City
# B: Richmond
# C: Salem
# D: Montgomery
#
#
# 14) What is the capital of Delaware?
#
# A: Dover
# B: Boise
# C: Olympia
# D: Nashville
#
#
# 15) What is the capital of Rhode Island?
#
# A: Jackson
# B: Salt Lake City
# C: Denver
# D: Providence
#
#
# 16) What is the capital of Louisiana?
#
# A: Little Rock
# B: Baton Rouge
# C: Santa Fe
# D: Boston
#
#
# 17) What is the capital of Montana?
#
# A: Boston
# B: Annapolis
# C: Charleston
# D: Helena
#
#
# 18) What is the capital of West Virginia?
#
# A: Charleston
# B: Concord
# C: Oklahoma City
# D: Sacramento
#
#
# 19) What is the capital of Connecticut?
#
# A: Salt Lake City
# B: Providence
# C: Austin
# D: Hartford
#
#
# 20) What is the capital of Mississippi?
#
# A: Little Rock
# B: Santa Fe
# C: Jackson
# D: Salt Lake City
#
#
# 21) What is the capital of Minnesota?
#
# A: Helena
# B: Charleston
# C: Juneau
# D: Saint Paul
#
#
# 22) What is the capital of Tennessee?
#
# A: Bismarck
# B: Olympia
# C: Nashville
# D: Helena
#
#
# 23) What is the capital of Illinois?
#
# A: Juneau
# B: Tallahassee
# C: Springfield
# D: Phoenix
#
#
# 24) What is the capital of North Carolina?
#
# A: Atlanta
# B: Olympia
# C: Little Rock
# D: Raleigh
#
#
# 25) What is the capital of Arkansas?
#
# A: Annapolis
# B: Little Rock
# C: Harrisburg
# D: Lincoln
#
#
# 26) What is the capital of Ohio?
#
# A: Richmond
# B: Columbus
# C: Lincoln
# D: Boise
#
#
# 27) What is the capital of Missouri?
#
# A: Augusta
# B: Jefferson City
# C: Montpelier
# D: Baton Rouge
#
#
# 28) What is the capital of Alaska?
#
# A: Bismarck
# B: Juneau
# C: Augusta
# D: Montpelier
#
#
# 29) What is the capital of Oklahoma?
#
# A: Annapolis
# B: Oklahoma City
# C: Dover
# D: Santa Fe
#
#
# 30) What is the capital of Kansas?
#
# A: Salem
# B: Topeka
# C: Montgomery
# D: Cheyenne
#
#
# 31) What is the capital of California?
#
# A: Montpelier
# B: Sacramento
# C: Boise
# D: Annapolis
#
#
# 32) What is the capital of Virginia?
#
# A: Richmond
# B: Jefferson City
# C: Columbia
# D: Augusta
#
#
# 33) What is the capital of New Jersey?
#
# A: Madison
# B: Saint Paul
# C: Cheyenne
# D: Trenton
#
#
# 34) What is the capital of Hawaii?
#
# A: Carson City
# B: Honolulu
# C: Phoenix
# D: Helena
#
#
# 35) What is the capital of Michigan?
#
# A: Honolulu
# B: Lansing
# C: Columbus
# D: Oklahoma City
#
#
# ...
#
# A: Augusta
# B: Salt Lake City
# C: Cheyenne
# D: Concord
#
#
# 24) What is the capital of Indiana?
#
# A: Juneau
# B: Indianapolis
# C: Austin
# D: Lansing
#
#
# 25) What is the capital of Alabama?
#
# A: Lincoln
# B: Montgomery
# C: Topeka
# D: Cheyenne
#
#
# 26) What is the capital of Connecticut?
#
# A: Hartford
# B: Honolulu
# C: Pierre
# D: Frankfort
#
#
# 27) What is the capital of Maryland?
#
# A: Charleston
# B: Madison
# C: Topeka
# D: Annapolis
#
#
# 28) What is the capital of North Carolina?
#
# A: Pierre
# B: Lansing
# C: Raleigh
# D: Juneau
#
#
# 29) What is the capital of Minnesota?
#
# A: Oklahoma City
# B: Saint Paul
# C: Augusta
# D: Nashville
#
#
# 30) What is the capital of Oregon?
#
# A: Jefferson City
# B: Salem
# C: Indianapolis
# D: Charleston
#
#
# 31) What is the capital of Idaho?
#
# A: Baton Rouge
# B: Madison
# C: Augusta
# D: Boise
#
#
# 32) What is the capital of Arizona?
#
# A: Trenton
# B: Lansing
# C: Saint Paul
# D: Phoenix
#
#
# 33) What is the capital of Nebraska?
#
# A: Nashville
# B: Lincoln
# C: Columbus
# D: Carson City
#
#
# 34) What is the capital of Delaware?
#
# A: Indianapolis
# B: Baton Rouge
# C: Dover
# D: Harrisburg
#
#
# 35) What is the capital of Texas?
#
# A: Albany
# B: Charleston
# C: Austin
# D: Saint Paul
#
#
# 36) What is the capital of New Jersey?
#
# A: Honolulu
# B: Trenton
# C: Olympia
# D: Raleigh
#
#
# 37) What is the capital of Georgia?
#
# A: Des Moines
# B: Atlanta
# C: Harrisburg
# D: Honolulu
#
#
# 38) What is the capital of Virginia?
#
# A: Concord
# B: Trenton
# C: Lansing
# D: Richmond
#
#
# 39) What is the capital of New Mexico?
#
# A: Salem
# B: Honolulu
# C: Indianapolis
# D: Santa Fe
#
#
# 40) What is the capital of Illinois?
#
# A: Carson City
# B: Charleston
# C: Springfield
# D: Salt Lake City
#
#
# 41) What is the capital of Pennsylvania?
#
# A: Harrisburg
# B: Salt Lake City
# C: Jefferson City
# D: Honolulu
#
#
# 42) What is the capital of Louisiana?
#
# A: Salt Lake City
# B: Baton Rouge
# C: Hartford
# D: Phoenix
#
#
# 43) What is the capital of Nevada?
#
# A: Salt Lake City
# B: Springfield
# C: Carson City
# D: Saint Paul
#
#
# 44) What is the capital of South Carolina?
#
# A: Jefferson City
# B: Carson City
# C: Columbia
# D: Dover
#
#
# 45) What is the capital of Michigan?
#
# A: Des Moines
# B: Concord
# C: Annapolis
# D: Lansing
#
#
# 46) What is the capital of Alaska?
#
# A: Concord
# B: Annapolis
# C: Austin
# D: Juneau
#
#
# 47) What is the capital of Ohio?
#
# A: Jackson
# B: Columbus
# C: Jefferson City
# D: Lansing
#
#
# 48) What is the capital of South Dakota?
#
# A: Pierre
# B: Sacramento
# C: Columbia
# D: Columbus
#
#
# 49) What is the capital of Arkansas?
#
# A: Atlanta
# B: Little Rock
# C: Jackson
# D: Sacramento
#
#
# 50) What is the capital of North Dakota?
#
# A: Cheyenne
# B: Albany
# C: Bismarck
# D: Austin
#
#
# 1) What is the capital of Texas?
#
# A: Albany
# B: Austin
# C: Denver
# D: Nashville
#
#
# 2) What is the capital of Indiana?
#
# A: Pierre
# B: Indianapolis
# C: Albany
# D: Hartford
#
#
# 3) What is the capital of New Jersey?
#
# A: Trenton
# B: Indianapolis
# C: Boston
# D: Jackson
#
#
# 4) What is the capital of Oklahoma?
#
# A: Oklahoma City
# B: Concord
# C: Carson City
# D: Madison
#
#
# 5) What is the capital of Mississippi?
#
# A: Oklahoma City
# B: Jackson
# C: Charleston
# D: Dover
#
#
# 6) What is the capital of Idaho?
#
# A: Boston
# B: Columbia
# C: Boise
# D: Santa Fe
#
#
# 7) What is the capital of Maryland?
#
# A: Olympia
# B: Annapolis
# C: Raleigh
# D: Sacramento
#
#
# 8) What is the capital of South Carolina?
#
# A: Honolulu
# B: Columbia
# C: Concord
# D: Saint Paul
#
#
# 9) What is the capital of Washington?
#
# A: Austin
# B: Topeka
# C: Olympia
# D: Montgomery
#
#
# 10) What is the capital of Rhode Island?
#
# A: Providence
# B: Honolulu
# C: Charleston
# D: Little Rock
#
#
# 11) What is the capital of Minnesota?
#
# A: Juneau
# B: Harrisburg
# C: Santa Fe
# D: Saint Paul
#
#
# 12) What is the capital of Colorado?
#
# A: Oklahoma City
# B: Denver
# C: Lansing
# D: Phoenix
#
#
# 13) What is the capital of Florida?
#
# A: Raleigh
# B: Austin
# C: Tallahassee
# D: Annapolis
#
#
# 14) What is the capital of Tennessee?
#
# A: Albany
# B: Nashville
# C: Juneau
# D: Denver
#
#
# 15) What is the capital of Louisiana?
#
# A: Columbus
# B: Austin
# C: Baton Rouge
# D: Juneau
#
#
# 16) What is the capital of New York?
#
# A: Little Rock
# B: Albany
# C: Carson City
# D: Lansing
#
#
# 17) What is the capital of Wisconsin?
#
# A: Madison
# B: Austin
# C: Columbus
# D: Montgomery
#
#
# 18) What is the capital of South Dakota?
#
# A: Boise
# B: Austin
# C: Sacramento
# D: Pierre
#
#
# 19) What is the capital of California?
#
# A: Sacramento
# B: Charleston
# C: Pierre
# D: Little Rock
#
#
# 20) What is the capital of Missouri?
#
# A: Jefferson City
# B: Santa Fe
# C: Olympia
# D: Albany
#
#
# 21) What is the capital of Pennsylvania?
#
# A: Cheyenne
# B: Pierre
# C: Concord
# D: Harrisburg
#
#
# 22) What is the capital of Kentucky?
#
# A: Indianapolis
# B: Augusta
# C: Frankfort
# D: Phoenix
#
#
# 23) What is the capital of West Virginia?
#
# A: Lansing
# B: Charleston
# C: Concord
# D: Atlanta
#
#
# 24) What is the capital of North Carolina?
#
# A: Salem
# B: Salt Lake City
# C: Raleigh
# D: Nashville
#
#
# 25) What is the capital of Montana?
#
# A: Denver
# B: Pierre
# C: Montgomery
# D: Helena
#
#
# 26) What is the capital of Delaware?
#
# A: Little Rock
# B: Dover
# C: Oklahoma City
# D: Charleston
#
#
# 27) What is the capital of Massachusetts?
#
# A: Lincoln
# B: Montgomery
# C: Lansing
# D: Boston
#
#
# 28) What is the capital of Arkansas?
#
# A: Montgomery
# B: Topeka
# C: Montpelier
# D: Little Rock
#
#
# 29) What is the capital of Virginia?
#
# A: Nashville
# B: Hartford
# C: Austin
# D: Richmond
#
#
# 30) What is the capital of Nebraska?
#
# A: Lincoln
# B: Charleston
# C: Boston
# D: Santa Fe
#
#
# 31) What is the capital of Alaska?
#
# A: Springfield
# B: Boise
# C: Juneau
# D: Cheyenne
#
#
# 32) What is the capital of Iowa?
#
# A: Columbia
# B: Concord
# C: Des Moines
# D: Atlanta
#
#
# 33) What is the capital of Kansas?
#
# A: Topeka
# B: Harrisburg
# C: Baton Rouge
# D: Indianapolis
#
#
# 34) What is the capital of Wyoming?
#
# A: Cheyenne
# B: Atlanta
# C: Nashville
# D: Annapolis
#
#
# 35) What is the capital of Georgia?
#
# A: Atlanta
# B: Providence
# C: Saint Paul
# D: Frankfort
#
#
# 36) What is the capital of Arizona?
#
# A: Honolulu
# B: Dover
# C: Phoenix
# D: Indianapolis
#
#
# 37) What is the capital of Nevada?
#
# A: Salt Lake City
# B: Madison
# C: Carson City
# D: Phoenix
#
#
# 38) What is the capital of Illinois?
#
# A: Springfield
# B: Providence
# C: Salt Lake City
# D: Montpelier
#
#
# 39) What is the capital of Vermont?
#
# A: Bismarck
# B: Montpelier
# C: Trenton
# D: Santa Fe
#
#
# 40) What is the capital of Michigan?
#
# A: Trenton
# B: Lansing
# C: Indianapolis
# D: Carson City
#
#
# 41) What is the capital of North Dakota?
#
# A: Jackson
# B: Bismarck
# C: Montgomery
# D: Denver
#
#
# 42) What is the capital of New Hampshire?
#
# A: Topeka
# B: Jefferson City
# C: Concord
# D: Tallahassee
#
#
# 43) What is the capital of Utah?
#
# A: Cheyenne
# B: Concord
# C: Juneau
# D: Salt Lake City
#
#
# 44) What is the capital of Oregon?
#
# A: Salem
# B: Annapolis
# C: Harrisburg
# D: Saint Paul
#
#
# 45) What is the capital of Ohio?
#
# A: Concord
# B: Columbus
# C: Boise
# D: Salem
#
#
# 46) What is the capital of Alabama?
#
# A: Lincoln
# B: Tallahassee
# C: Montgomery
# D: Bismarck
#
#
# 47) What is the capital of Connecticut?
#
# A: Pierre
# B: Hartford
# C: Olympia
# D: Salem
#
#
# 48) What is the capital of New Mexico?
#
# A: Albany
# B: Santa Fe
# C: Austin
# D: Montpelier
#
#
# 49) What is the capital of Hawaii?
#
# A: Hartford
# B: Little Rock
# C: Honolulu
# D: Harrisburg
#
#
# 50) What is the capital of Maine?
#
# A: Helena
# B: Columbia
# C: Jefferson City
# D: Augusta
#
#
# 1) What is the capital of New York?
#
# A: Albany
# B: Springfield
# C: Denver
# D: Lansing
#
#
# 2) What is the capital of Virginia?
#
# A: Madison
# B: Little Rock
# C: Richmond
# D: Tallahassee
#
#
# 3) What is the capital of Oregon?
#
# A: Jefferson City
# B: Salem
# C: Denver
# D: Cheyenne
#
#
# 4) What is the capital of Rhode Island?
#
# A: Carson City
# B: Olympia
# C: Atlanta
# D: Providence
#
#
# 5) What is the capital of Illinois?
#
# A: Springfield
# B: Sacramento
# C: Olympia
# D: Indianapolis
#
#
# 6) What is the capital of Kansas?
#
# A: Dover
# B: Bismarck
# C: Richmond
# D: Topeka
#
#
# 7) What is the capital of Washington?
#
# A: Richmond
# B: Des Moines
# C: Indianapolis
# D: Olympia
#
#
# 8) What is the capital of Arkansas?
#
# A: Tallahassee
# B: Dover
# C: Augusta
# D: Little Rock
#
#
# 9) What is the capital of Tennessee?
#
# A: Charleston
# B: Nashville
# C: Jefferson City
# D: Richmond
#
#
# 10) What is the capital of Wisconsin?
#
# A: Augusta
# B: Madison
# C: Boston
# D: Santa Fe
#
#
# 11) What is the capital of North Carolina?
#
# A: Springfield
# B: Helena
# C: Concord
# D: Raleigh
#
#
# 12) What is the capital of Idaho?
#
# A: Santa Fe
# B: Boston
# C: Denver
# D: Boise
#
#
# 13) What is the capital of Wyoming?
#
# A: Frankfort
# B: Juneau
# C: Denver
# D: Cheyenne
#
#
# 14) What is the capital of Delaware?
#
# A: Columbus
# B: Dover
# C: Austin
# D: Concord
#
#
# 15) What is the capital of Pennsylvania?
#
# A: Harrisburg
# B: Lansing
# C: Phoenix
# D: Austin
#
#
# 16) What is the capital of South Dakota?
#
# A: Pierre
# B: Saint Paul
# C: Augusta
# D: Boise
#
#
# 17) What is the capital of Nevada?
#
# A: Springfield
# B: Carson City
# C: Little Rock
# D: Salt Lake City
#
#
# 18) What is the capital of Mississippi?
#
# A: Indianapolis
# B: Honolulu
# C: Columbus
# D: Jackson
#
#
# 19) What is the capital of Colorado?
#
# A: Salem
# B: Denver
# C: Concord
# D: Sacramento
#
#
# 20) What is the capital of West Virginia?
#
# A: Dover
# B: Charleston
# C: Lincoln
# D: Jefferson City
#
#
# 21) What is the capital of Nebraska?
#
# A: Oklahoma City
# B: Montpelier
# C: Lincoln
# D: Jackson
#
#
# 22) What is the capital of Texas?
#
# A: Raleigh
# B: Jackson
# C: Sacramento
# D: Austin
#
#
# 23) What is the capital of Iowa?
#
# A: Boise
# B: Cheyenne
# C: Bismarck
# D: Des Moines
#
#
# 24) What is the capital of Hawaii?
#
# A: Honolulu
# B: Charleston
# C: Springfield
# D: Pierre
#
#
# 25) What is the capital of New Jersey?
#
# A: Charleston
# B: Providence
# C: Montpelier
# D: Trenton
#
#
# 26) What is the capital of Maryland?
#
# A: Annapolis
# B: Nashville
# C: Salt Lake City
# D: Topeka
#
#
# 27) What is the capital of Connecticut?
#
# A: Boston
# B: Indianapolis
# C: Hartford
# D: Montpelier
#
#
# 28) What is the capital of Indiana?
#
# A: Saint Paul
# B: Santa Fe
# C: Indianapolis
# D: Hartford
#
#
# 29) What is the capital of Minnesota?
#
# A: Montpelier
# B: Saint Paul
# C: Hartford
# D: Trenton
#
#
# 30) What is the capital of Montana?
#
# A: Richmond
# B: Nashville
# C: Helena
# D: Baton Rouge
#
#
# 31) What is the capital of New Mexico?
#
# A: Carson City
# B: Santa Fe
# C: Honolulu
# D: Augusta
#
#
# 32) What is the capital of Maine?
#
# A: Des Moines
# B: Augusta
# C: Saint Paul
# D: Oklahoma City
#
#
# 33) What is the capital of Michigan?
#
# A: Dover
# B: Juneau
# C: Bismarck
# D: Lansing
#
#
# 34) What is the capital of Florida?
#
# A: Tallahassee
# B: Albany
# C: Jefferson City
# D: Santa Fe
#
#
# 35) What is the capital of Kentucky?
#
# A: Columbia
# B: Hartford
# C: Saint Paul
# D: Frankfort
#
#
# 36) What is the capital of Alabama?
#
# A: Montgomery
# B: Frankfort
# C: Springfield
# D: Cheyenne
#
#
# 37) What is the capital of Georgia?
#
# A: Helena
# B: Cheyenne
# C: Atlanta
# D: Indianapolis
#
#
# 38) What is the capital of Missouri?
#
# A: Jefferson City
# B: Topeka
# C: Harrisburg
# D: Honolulu
#
#
# 39) What is the capital of Ohio?
#
# A: Columbus
# B: Baton Rouge
# C: Richmond
# D: Phoenix
#
#
# 40) What is the capital of Oklahoma?
#
# A: Honolulu
# B: Montpelier
# C: Oklahoma City
# D: Boston
#
#
# 41) What is the capital of Vermont?
#
# A: Austin
# B: Montpelier
# C: Madison
# D: Oklahoma City
#
#
# 42) What is the capital of Arizona?
#
# A: Phoenix
# B: Charleston
# C: Saint Paul
# D: Jefferson City
#
#
# 43) What is the capital of Massachusetts?
#
# A: Bismarck
# B: Juneau
# C: Providence
# D: Boston
#
#
# 44) What is the capital of South Carolina?
#
# A: Cheyenne
# B: Jackson
# C: Hartford
# D: Columbia
#
#
# 45) What is the capital of Utah?
#
# A: Santa Fe
# B: Saint Paul
# C: Salt Lake City
# D: Cheyenne
#
#
# 46) What is the capital of New Hampshire?
#
# A: Madison
# B: Concord
# C: Lincoln
# D: Albany
#
#
# 47) What is the capital of California?
#
# A: Little Rock
# B: Cheyenne
# C: Raleigh
# D: Sacramento
#
#
# 48) What is the capital of North Dakota?
#
# A: Trenton
# B: Cheyenne
# C: Bismarck
# D: Des Moines
#
#
# 49) What is the capital of Alaska?
#
# A: Jackson
# B: Juneau
# C: Nashville
# D: Santa Fe
#
#
# 50) What is the capital of Louisiana?
#
# A: Dover
# B: Baton Rouge
# C: Nashville
# D: Raleigh
#
#
# 1) What is the capital of Arizona?
#
# A: Boise
# B: Des Moines
# C: Indianapolis
# D: Phoenix
#
#
# 2) What is the capital of Illinois?
#
# A: Springfield
# B: Salt Lake City
# C: Honolulu
# D: Little Rock
#
#
# 3) What is the capital of New Hampshire?
#
# A: Madison
# B: Cheyenne
# C: Concord
# D: Boise
#
#
# 4) What is the capital of Oregon?
#
# A: Tallahassee
# B: Salem
# C: Topeka
# D: Carson City
#
#
# 5) What is the capital of Maryland?
#
# A: Montpelier
# B: Annapolis
# C: Raleigh
# D: Jefferson City
#
#
# 6) What is the capital of Hawaii?
#
# A: Dover
# B: Jefferson City
# C: Saint Paul
# D: Honolulu
#
#
# 7) What is the capital of New Jersey?
#
# A: Helena
# B: Trenton
# C: Denver
# D: Annapolis
#
#
# 8) What is the capital of Wisconsin?
#
# A: Carson City
# B: Madison
# C: Cheyenne
# D: Salt Lake City
#
#
# 9) What is the capital of Alaska?
#
# A: Juneau
# B: Nashville
# C: Atlanta
# D: Boston
#
#
# 10) What is the capital of Kansas?
#
# A: Frankfort
# B: Denver
# C: Raleigh
# D: Topeka
#
#
# 11) What is the capital of Colorado?
#
# A: Denver
# B: Phoenix
# C: Lansing
# D: Albany
#
#
# 12) What is the capital of Massachusetts?
#
# A: Oklahoma City
# B: Madison
# C: Boston
# D: Little Rock
#
#
# 13) What is the capital of Texas?
#
# A: Jefferson City
# B: Annapolis
# C: Denver
# D: Austin
#
#
# 14) What is the capital of Pennsylvania?
#
# A: Lincoln
# B: Harrisburg
# C: Des Moines
# D: Dover
#
#
# 15) What is the capital of Louisiana?
#
# A: Topeka
# B: Jefferson City
# C: Boston
# D: Baton Rouge
#
#
# 16) What is the capital of Maine?
#
# A: Des Moines
# B: Santa Fe
# C: Charleston
# D: Augusta
#
#
# 17) What is the capital of Missouri?
#
# A: Dover
# B: Pierre
# C: Topeka
# D: Jefferson City
#
#
# 18) What is the capital of Kentucky?
#
# A: Frankfort
# B: Little Rock
# C: Atlanta
# D: Jefferson City
#
#
# 19) What is the capital of South Carolina?
#
# A: Columbia
# B: Oklahoma City
# C: Madison
# D: Honolulu
#
#
# 20) What is the capital of Wyoming?
#
# A: Cheyenne
# B: Springfield
# C: Jackson
# D: Helena
#
#
# 21) What is the capital of Oklahoma?
#
# A: Harrisburg
# B: Oklahoma City
# C: Madison
# D: Saint Paul
#
#
# 22) What is the capital of Idaho?
#
# A: Lincoln
# B: Boise
# C: Nashville
# D: Jefferson City
#
#
# 23) What is the capital of Washington?
#
# A: Montgomery
# B: Des Moines
# C: Boise
# D: Olympia
#
#
# 24) What is the capital of Indiana?
#
# A: Annapolis
# B: Tallahassee
# C: Indianapolis
# D: Boise
#
#
# 25) What is the capital of Mississippi?
#
# A: Trenton
# B: Salem
# C: Austin
# D: Jackson
#
#
# 26) What is the capital of North Carolina?
#
# A: Frankfort
# B: Raleigh
# C: Montpelier
# D: Honolulu
#
#
# 27) What is the capital of Montana?
#
# A: Annapolis
# B: Helena
# C: Santa Fe
# D: Lansing
#
#
# 28) What is the capital of Arkansas?
#
# A: Tallahassee
# B: Charleston
# C: Little Rock
# D: Lincoln
#
#
# 29) What is the capital of New York?
#
# A: Atlanta
# B: Jackson
# C: Boise
# D: Albany
#
#
# 30) What is the capital of Rhode Island?
#
# A: Albany
# B: Jackson
# C: Providence
# D: Columbus
#
#
# 31) What is the capital of Utah?
#
# A: Indianapolis
# B: Salt Lake City
# C: Boise
# D: Montpelier
#
#
# 32) What is the capital of Minnesota?
#
# A: Lincoln
# B: Indianapolis
# C: Saint Paul
# D: Boise
#
#
# 33) What is the capital of Tennessee?
#
# A: Montpelier
# B: Boston
# C: Nashville
# D: Saint Paul
#
#
# 34) What is the capital of Iowa?
#
# A: Des Moines
# B: Salem
# C: Dover
# D: Annapolis
#
#
# 35) What is the capital of Georgia?
#
# A: Frankfort
# B: Richmond
# C: Jackson
# D: Atlanta
#
#
# 36) What is the capital of Connecticut?
#
# A: Nashville
# B: Hartford
# C: Charleston
# D: Sacramento
#
#
# 37) What is the capital of Vermont?
#
# A: Montpelier
# B: Helena
# C: Phoenix
# D: Cheyenne
#
#
# 38) What is the capital of Virginia?
#
# A: Indianapolis
# B: Olympia
# C: Richmond
# D: Springfield
#
#
# 39) What is the capital of North Dakota?
#
# A: Bismarck
# B: Richmond
# C: Juneau
# D: Pierre
#
#
# 40) What is the capital of Ohio?
#
# A: Helena
# B: Trenton
# C: Carson City
# D: Columbus
#
#
# 41) What is the capital of New Mexico?
#
# A: Salem
# B: Pierre
# C: Columbia
# D: Santa Fe
#
#
# 42) What is the capital of Alabama?
#
# A: Montgomery
# B: Indianapolis
# C: Des Moines
# D: Annapolis
#
#
# 43) What is the capital of South Dakota?
#
# A: Salt Lake City
# B: Charleston
# C: Columbus
# D: Pierre
#
#
# 44) What is the capital of Nebraska?
#
# A: Salt Lake City
# B: Concord
# C: Lincoln
# D: Topeka
#
#
# 45) What is the capital of California?
#
# A: Sacramento
# B: Lincoln
# C: Juneau
# D: Denver
#
#
# 46) What is the capital of Michigan?
#
# A: Cheyenne
# B: Lansing
# C: Bismarck
# D: Juneau
#
#
# 47) What is the capital of Nevada?
#
# A: Jefferson City
# B: Springfield
# C: Carson City
# D: Frankfort
#
#
# 48) What is the capital of Delaware?
#
# A: Juneau
# B: Lincoln
# C: Albany
# D: Dover
#
#
# 49) What is the capital of West Virginia?
#
# A: Charleston
# B: Helena
# C: Des Moines
# D: Springfield
#
#
# 50) What is the capital of Florida?
#
# A: Tallahassee
# B: Bismarck
# C: Albany
# D: Atlanta
